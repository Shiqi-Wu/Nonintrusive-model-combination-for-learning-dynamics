# %%
# %%html
# <style type='text/css'>
# .CodeMirror{
# font-size: 22px;
# </style>
# Out:
# <style type='text/css'>
# .CodeMirror{
# font-size: 22px;
# </style>

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
import numpy as np
import matplotlib.pyplot as plt
from Toy_model import *
import sys 
sys.path.append("../utils") 
from Evaluation_plot import *

# %% [markdown]
# ## Angle

# %%
model2 = MethodCriterion()
model2.build_A()

# %%
model2.generate_training_data(500, 10, dlt_t = 0.001)

# %%
error_bound = 1e-6

# %%
para_set = [i / 5 for i in range(-10, 10, 1)]
err_trajs = []
for para in para_set:
    print(para)
    err = model2.testing(para, error_bound)
    err_trajs.append(err)
# Out:
# -2.0
# -2.0
# parameters are 0.460563 and 0.338678, and the error is 0.624795
# parameters are 0.349988 and 0.257074, and the error is 0.473806
# parameters are 0.266134 and 0.195191, and the error is 0.359305
# parameters are 0.202544 and 0.148262, and the error is 0.272474
# parameters are 0.154322 and 0.112675, and the error is 0.206628
# parameters are 0.117753 and 0.085687, and the error is 0.156694
# parameters are 0.090022 and 0.065221, and the error is 0.118827
# parameters are 0.068992 and 0.049701, and the error is 0.090111
# parameters are 0.053044 and 0.037932, and the error is 0.068334
# parameters are 0.040950 and 0.029007, and the error is 0.051821
# parameters are 0.031779 and 0.022239, and the error is 0.039297
# parameters are 0.024824 and 0.017106, and the error is 0.029801
# parameters are 0.019550 and 0.013214, and the error is 0.022599
# parameters are 0.015551 and 0.010262, and the error is 0.017138
# parameters are 0.012518 and 0.008024, and the error is 0.012996
# parameters are 0.010218 and 0.006327, and the error is 0.009855
# parameters are 0.008473 and 0.005039, and the error is 0.007474
# parameters are 0.007151 and 0.004063, and the error is 0.005668
# parameters are 0.006148 and 0.003323, and the error is 0.004298
# parameters are 0.005387 and 0.002762, and the error is 0.003259
# parameters are 0.004810 and 0.002336, and the error is 0.002472
# parameters are 0.004373 and 0.002013, and the error is 0.001874
# parameters are 0.004041 and 0.001768, and the error is 0.001421
# parameters are 0.003789 and 0.001583, and the error is 0.001078
# parameters are 0.003599 and 0.001442, and the error is 0.000817
# parameters are 0.003454 and 0.001335, and the error is 0.000620
# parameters are 0.003344 and 0.001254, and the error is 0.000470
# parameters are 0.003261 and 0.001193, and the error is 0.000356
# parameters are 0.003198 and 0.001146, and the error is 0.000270
# parameters are 0.003150 and 0.001111, and the error is 0.000205
# parameters are 0.003114 and 0.001084, and the error is 0.000155
# parameters are 0.003086 and 0.001064, and the error is 0.000118
# parameters are 0.003065 and 0.001048, and the error is 0.000089
# parameters are 0.003050 and 0.001037, and the error is 0.000068
# parameters are 0.003038 and 0.001028, and the error is 0.000051
# parameters are 0.003029 and 0.001021, and the error is 0.000039
# parameters are 0.003022 and 0.001016, and the error is 0.000030
# parameters are 0.003016 and 0.001012, and the error is 0.000022
# parameters are 0.003012 and 0.001009, and the error is 0.000017
# parameters are 0.003009 and 0.001007, and the error is 0.000013
# parameters are 0.003007 and 0.001005, and the error is 0.000010
# parameters are 0.003005 and 0.001004, and the error is 0.000007
# parameters are 0.003004 and 0.001003, and the error is 0.000006
# parameters are 0.003003 and 0.001002, and the error is 0.000004
# parameters are 0.003002 and 0.001002, and the error is 0.000003
# parameters are 0.003002 and 0.001001, and the error is 0.000002
# parameters are 0.003001 and 0.001001, and the error is 0.000002
# parameters are 0.003001 and 0.001001, and the error is 0.000001
# parameters are 0.003001 and 0.001001, and the error is 0.000001
# parameters are 0.003001 and 0.001000, and the error is 0.000001
# -1.8
# -1.8
# parameters are 0.396383 and 0.341756, and the error is 0.630490
# parameters are 0.276390 and 0.237868, and the error is 0.438270
# parameters are 0.192979 and 0.165653, and the error is 0.304653
# parameters are 0.134998 and 0.115455, and the error is 0.211772
# parameters are 0.094694 and 0.080560, and the error is 0.147208
# parameters are 0.066678 and 0.056305, and the error is 0.102328
# parameters are 0.047203 and 0.039444, and the error is 0.071131
# parameters are 0.033666 and 0.027723, and the error is 0.049445
# parameters are 0.024256 and 0.019576, and the error is 0.034370
# parameters are 0.017714 and 0.013913, and the error is 0.023892
# parameters are 0.013167 and 0.009976, and the error is 0.016608
# parameters are 0.010007 and 0.007239, and the error is 0.011544
# parameters are 0.007810 and 0.005337, and the error is 0.008025
# parameters are 0.006282 and 0.004015, and the error is 0.005578
# parameters are 0.005221 and 0.003096, and the error is 0.003878
# parameters are 0.004483 and 0.002457, and the error is 0.002695
# parameters are 0.003970 and 0.002013, and the error is 0.001874
# parameters are 0.003613 and 0.001704, and the error is 0.001302
# parameters are 0.003365 and 0.001489, and the error is 0.000905
# parameters are 0.003193 and 0.001340, and the error is 0.000629
# parameters are 0.003073 and 0.001236, and the error is 0.000437
# parameters are 0.002990 and 0.001164, and the error is 0.000304
# parameters are 0.002932 and 0.001114, and the error is 0.000211
# parameters are 0.002892 and 0.001079, and the error is 0.000147
# parameters are 0.002864 and 0.001055, and the error is 0.000102
# parameters are 0.002844 and 0.001038, and the error is 0.000071
# parameters are 0.002831 and 0.001027, and the error is 0.000049
# parameters are 0.002821 and 0.001019, and the error is 0.000034
# parameters are 0.002815 and 0.001013, and the error is 0.000024
# parameters are 0.002810 and 0.001009, and the error is 0.000017
# parameters are 0.002807 and 0.001006, and the error is 0.000012
# parameters are 0.002805 and 0.001004, and the error is 0.000008
# parameters are 0.002803 and 0.001003, and the error is 0.000006
# parameters are 0.002802 and 0.001002, and the error is 0.000004
# parameters are 0.002802 and 0.001001, and the error is 0.000003
# parameters are 0.002801 and 0.001001, and the error is 0.000002
# parameters are 0.002801 and 0.001001, and the error is 0.000001
# parameters are 0.002801 and 0.001000, and the error is 0.000001
# -1.6
# -1.6
# parameters are 0.315345 and 0.328473, and the error is 0.605912
# parameters are 0.193122 and 0.200494, and the error is 0.369116
# parameters are 0.118664 and 0.122530, and the error is 0.224863
# parameters are 0.073305 and 0.075035, and the error is 0.136984
# parameters are 0.045673 and 0.046101, and the error is 0.083450
# parameters are 0.028840 and 0.028475, and the error is 0.050837
# parameters are 0.018585 and 0.017738, and the error is 0.030969
# parameters are 0.012338 and 0.011197, and the error is 0.018866
# parameters are 0.008532 and 0.007212, and the error is 0.011493
# parameters are 0.006214 and 0.004784, and the error is 0.007002
# parameters are 0.004802 and 0.003305, and the error is 0.004265
# parameters are 0.003941 and 0.002404, and the error is 0.002598
# parameters are 0.003417 and 0.001855, and the error is 0.001583
# parameters are 0.003098 and 0.001521, and the error is 0.000964
# parameters are 0.002903 and 0.001317, and the error is 0.000587
# parameters are 0.002785 and 0.001193, and the error is 0.000358
# parameters are 0.002713 and 0.001118, and the error is 0.000218
# parameters are 0.002669 and 0.001072, and the error is 0.000133
# parameters are 0.002642 and 0.001044, and the error is 0.000081
# parameters are 0.002625 and 0.001027, and the error is 0.000049
# parameters are 0.002615 and 0.001016, and the error is 0.000030
# parameters are 0.002609 and 0.001010, and the error is 0.000018
# parameters are 0.002606 and 0.001006, and the error is 0.000011
# parameters are 0.002604 and 0.001004, and the error is 0.000007
# parameters are 0.002602 and 0.001002, and the error is 0.000004
# parameters are 0.002601 and 0.001001, and the error is 0.000003
# parameters are 0.002601 and 0.001001, and the error is 0.000002
# parameters are 0.002600 and 0.001001, and the error is 0.000001
# -1.4
# -1.4
# parameters are 0.215813 and 0.283656, and the error is 0.522989
# parameters are 0.107716 and 0.140487, and the error is 0.258088
# parameters are 0.054372 and 0.069835, and the error is 0.127363
# parameters are 0.028048 and 0.034969, and the error is 0.062852
# parameters are 0.015057 and 0.017763, and the error is 0.031016
# parameters are 0.008646 and 0.009272, and the error is 0.015306
# parameters are 0.005482 and 0.005082, and the error is 0.007553
# parameters are 0.003921 and 0.003015, and the error is 0.003727
# parameters are 0.003151 and 0.001994, and the error is 0.001839
# parameters are 0.002770 and 0.001491, and the error is 0.000908
# parameters are 0.002583 and 0.001242, and the error is 0.000448
# parameters are 0.002490 and 0.001119, and the error is 0.000221
# parameters are 0.002445 and 0.001059, and the error is 0.000109
# parameters are 0.002422 and 0.001029, and the error is 0.000054
# parameters are 0.002411 and 0.001014, and the error is 0.000027
# parameters are 0.002405 and 0.001007, and the error is 0.000013
# parameters are 0.002403 and 0.001003, and the error is 0.000006
# parameters are 0.002401 and 0.001002, and the error is 0.000003
# parameters are 0.002401 and 0.001001, and the error is 0.000002
# parameters are 0.002400 and 0.001000, and the error is 0.000001
# -1.2
# -1.2
# parameters are 0.103284 and 0.183124, and the error is 0.336978
# parameters are 0.037064 and 0.063815, and the error is 0.116224
# parameters are 0.014225 and 0.022665, and the error is 0.040086
# parameters are 0.006347 and 0.008472, and the error is 0.013826
# parameters are 0.003630 and 0.003577, and the error is 0.004768
# parameters are 0.002693 and 0.001889, and the error is 0.001645
# parameters are 0.002370 and 0.001307, and the error is 0.000567
# parameters are 0.002259 and 0.001106, and the error is 0.000196
# parameters are 0.002220 and 0.001036, and the error is 0.000067
# parameters are 0.002207 and 0.001013, and the error is 0.000023
# parameters are 0.002202 and 0.001004, and the error is 0.000008
# parameters are 0.002201 and 0.001001, and the error is 0.000003
# parameters are 0.002200 and 0.001001, and the error is 0.000001
# -1.0
# -1.0
# parameters are 0.001370 and -0.000776, and the error is 0.003286
# parameters are 0.001888 and 0.000685, and the error is 0.000582
# parameters are 0.001980 and 0.000944, and the error is 0.000103
# parameters are 0.001996 and 0.000990, and the error is 0.000018
# parameters are 0.001999 and 0.000998, and the error is 0.000003
# parameters are 0.002000 and 0.001000, and the error is 0.000001
# -0.8
# -0.8
# parameters are -0.040262 and -0.270319, and the error is 0.502012
# parameters are 0.000140 and -0.009705, and the error is 0.019806
# parameters are 0.001735 and 0.000578, and the error is 0.000781
# parameters are 0.001797 and 0.000983, and the error is 0.000031
# parameters are 0.001800 and 0.000999, and the error is 0.000001
# parameters are 0.001800 and 0.001000, and the error is 0.000000
# -0.6
# -0.6
# parameters are 0.026828 and -0.559966, and the error is 1.037937
# parameters are 0.001687 and -0.000932, and the error is 0.003575
# parameters are 0.001600 and 0.000993, and the error is 0.000012
# parameters are 0.001600 and 0.001000, and the error is 0.000000
# -0.4
# -0.4
# parameters are 0.188809 and -0.764020, and the error is 1.415492
# parameters are 0.018833 and -0.070164, and the error is 0.131673
# parameters are 0.003022 and -0.005620, and the error is 0.012249
# parameters are 0.001551 and 0.000384, and the error is 0.001139
# parameters are 0.001414 and 0.000943, and the error is 0.000106
# parameters are 0.001401 and 0.000995, and the error is 0.000010
# parameters are 0.001400 and 0.001000, and the error is 0.000001
# -0.2
# -0.2
# parameters are 0.374959 and -0.838960, and the error is 1.554150
# parameters are 0.095700 and -0.211373, and the error is 0.392946
# parameters are 0.025093 and -0.052696, and the error is 0.099351
# parameters are 0.007241 and -0.012576, and the error is 0.025120
# parameters are 0.002727 and -0.002433, and the error is 0.006351
# parameters are 0.001586 and 0.000132, and the error is 0.001606
# parameters are 0.001298 and 0.000781, and the error is 0.000406
# parameters are 0.001225 and 0.000945, and the error is 0.000103
# parameters are 0.001206 and 0.000986, and the error is 0.000026
# parameters are 0.001202 and 0.000996, and the error is 0.000007
# parameters are 0.001200 and 0.000999, and the error is 0.000002
# parameters are 0.001200 and 0.001000, and the error is 0.000000
# 0.0
# 0.0
# parameters are 0.530658 and -0.820210, and the error is 1.519457
# parameters are 0.221089 and -0.340237, and the error is 0.631380
# parameters are 0.092453 and -0.140794, and the error is 0.262357
# parameters are 0.039002 and -0.057920, and the error is 0.109017
# parameters are 0.016791 and -0.023483, and the error is 0.045300
# parameters are 0.007562 and -0.009173, and the error is 0.018824
# parameters are 0.003727 and -0.003227, and the error is 0.007822
# parameters are 0.002133 and -0.000757, and the error is 0.003250
# parameters are 0.001471 and 0.000270, and the error is 0.001351
# parameters are 0.001196 and 0.000697, and the error is 0.000561
# parameters are 0.001081 and 0.000874, and the error is 0.000233
# parameters are 0.001034 and 0.000948, and the error is 0.000097
# parameters are 0.001014 and 0.000978, and the error is 0.000040
# parameters are 0.001006 and 0.000991, and the error is 0.000017
# parameters are 0.001002 and 0.000996, and the error is 0.000007
# parameters are 0.001001 and 0.000998, and the error is 0.000003
# parameters are 0.001000 and 0.000999, and the error is 0.000001
# parameters are 0.001000 and 0.001000, and the error is 0.000000
# 0.2
# 0.2
# parameters are 0.642470 and -0.758397, and the error is 1.405087
# parameters are 0.353460 and -0.416362, and the error is 0.772232
# parameters are 0.194621 and -0.228381, and the error is 0.424416
# parameters are 0.107323 and -0.125067, and the error is 0.233258
# parameters are 0.059345 and -0.068286, and the error is 0.128198
# parameters are 0.032976 and -0.037079, and the error is 0.070457
# parameters are 0.018484 and -0.019928, and the error is 0.038723
# parameters are 0.010519 and -0.010502, and the error is 0.021282
# parameters are 0.006142 and -0.005322, and the error is 0.011697
# parameters are 0.003736 and -0.002474, and the error is 0.006428
# parameters are 0.002413 and -0.000909, and the error is 0.003533
# parameters are 0.001687 and -0.000049, and the error is 0.001942
# parameters are 0.001287 and 0.000423, and the error is 0.001067
# parameters are 0.001068 and 0.000683, and the error is 0.000587
# parameters are 0.000947 and 0.000826, and the error is 0.000322
# parameters are 0.000881 and 0.000904, and the error is 0.000177
# parameters are 0.000844 and 0.000947, and the error is 0.000097
# parameters are 0.000824 and 0.000971, and the error is 0.000054
# parameters are 0.000813 and 0.000984, and the error is 0.000029
# parameters are 0.000807 and 0.000991, and the error is 0.000016
# parameters are 0.000804 and 0.000995, and the error is 0.000009
# parameters are 0.000802 and 0.000997, and the error is 0.000005
# parameters are 0.000801 and 0.000999, and the error is 0.000003
# parameters are 0.000801 and 0.000999, and the error is 0.000001
# parameters are 0.000800 and 0.001000, and the error is 0.000001
# 0.4
# 0.4
# parameters are 0.717788 and -0.685322, and the error is 1.269879
# parameters are 0.467569 and -0.445872, and the error is 0.826832
# parameters are 0.304648 and -0.289963, and the error is 0.538360
# parameters are 0.198569 and -0.188449, and the error is 0.350532
# parameters are 0.129500 and -0.122352, and the error is 0.228235
# parameters are 0.084528 and -0.079316, and the error is 0.148606
# parameters are 0.055247 and -0.051295, and the error is 0.096759
# parameters are 0.036181 and -0.033050, and the error is 0.063001
# parameters are 0.023767 and -0.021170, and the error is 0.041021
# parameters are 0.015684 and -0.013435, and the error is 0.026709
# parameters are 0.010422 and -0.008399, and the error is 0.017391
# parameters are 0.006995 and -0.005120, and the error is 0.011323
# parameters are 0.004764 and -0.002985, and the error is 0.007373
# parameters are 0.003311 and -0.001594, and the error is 0.004800
# parameters are 0.002365 and -0.000689, and the error is 0.003126
# parameters are 0.001749 and -0.000100, and the error is 0.002035
# parameters are 0.001348 and 0.000284, and the error is 0.001325
# parameters are 0.001087 and 0.000534, and the error is 0.000863
# parameters are 0.000917 and 0.000696, and the error is 0.000562
# parameters are 0.000807 and 0.000802, and the error is 0.000366
# parameters are 0.000735 and 0.000871, and the error is 0.000238
# parameters are 0.000688 and 0.000916, and the error is 0.000155
# parameters are 0.000657 and 0.000945, and the error is 0.000101
# parameters are 0.000637 and 0.000964, and the error is 0.000066
# parameters are 0.000624 and 0.000977, and the error is 0.000043
# parameters are 0.000616 and 0.000985, and the error is 0.000028
# parameters are 0.000610 and 0.000990, and the error is 0.000018
# parameters are 0.000607 and 0.000994, and the error is 0.000012
# parameters are 0.000604 and 0.000996, and the error is 0.000008
# parameters are 0.000603 and 0.000997, and the error is 0.000005
# parameters are 0.000602 and 0.000998, and the error is 0.000003
# parameters are 0.000601 and 0.000999, and the error is 0.000002
# parameters are 0.000601 and 0.000999, and the error is 0.000001
# parameters are 0.000601 and 0.001000, and the error is 0.000001
# 0.6
# 0.6
# parameters are 0.767528 and -0.615181, and the error is 1.140099
# parameters are 0.557297 and -0.446316, and the error is 0.827655
# parameters are 0.404679 and -0.323729, and the error is 0.600836
# parameters are 0.293887 and -0.234737, and the error is 0.436177
# parameters are 0.213457 and -0.170134, and the error is 0.316643
# parameters are 0.155069 and -0.123235, and the error is 0.229867
# parameters are 0.112682 and -0.089188, and the error is 0.166872
# parameters are 0.081911 and -0.064472, and the error is 0.121141
# parameters are 0.059573 and -0.046529, and the error is 0.087942
# parameters are 0.043357 and -0.033504, and the error is 0.063842
# parameters are 0.031584 and -0.024048, and the error is 0.046346
# parameters are 0.023038 and -0.017184, and the error is 0.033645
# parameters are 0.016834 and -0.012200, and the error is 0.024424
# parameters are 0.012330 and -0.008583, and the error is 0.017731
# parameters are 0.009061 and -0.005957, and the error is 0.012872
# parameters are 0.006687 and -0.004050, and the error is 0.009344
# parameters are 0.004964 and -0.002666, and the error is 0.006783
# parameters are 0.003713 and -0.001661, and the error is 0.004924
# parameters are 0.002805 and -0.000932, and the error is 0.003575
# parameters are 0.002146 and -0.000403, and the error is 0.002595
# parameters are 0.001668 and -0.000018, and the error is 0.001884
# parameters are 0.001320 and 0.000261, and the error is 0.001368
# parameters are 0.001068 and 0.000463, and the error is 0.000993
# parameters are 0.000885 and 0.000610, and the error is 0.000721
# parameters are 0.000752 and 0.000717, and the error is 0.000523
# parameters are 0.000656 and 0.000795, and the error is 0.000380
# parameters are 0.000586 and 0.000851, and the error is 0.000276
# parameters are 0.000535 and 0.000892, and the error is 0.000200
# parameters are 0.000498 and 0.000921, and the error is 0.000145
# parameters are 0.000471 and 0.000943, and the error is 0.000105
# parameters are 0.000452 and 0.000959, and the error is 0.000077
# parameters are 0.000437 and 0.000970, and the error is 0.000056
# parameters are 0.000427 and 0.000978, and the error is 0.000040
# parameters are 0.000420 and 0.000984, and the error is 0.000029
# parameters are 0.000414 and 0.000989, and the error is 0.000021
# parameters are 0.000410 and 0.000992, and the error is 0.000015
# parameters are 0.000408 and 0.000994, and the error is 0.000011
# parameters are 0.000405 and 0.000996, and the error is 0.000008
# parameters are 0.000404 and 0.000997, and the error is 0.000006
# parameters are 0.000403 and 0.000998, and the error is 0.000004
# parameters are 0.000402 and 0.000998, and the error is 0.000003
# parameters are 0.000402 and 0.000999, and the error is 0.000002
# parameters are 0.000401 and 0.000999, and the error is 0.000002
# parameters are 0.000401 and 0.000999, and the error is 0.000001
# parameters are 0.000401 and 0.001000, and the error is 0.000001
# 0.8
# 0.8
# parameters are 0.800372 and -0.552763, and the error is 1.024609
# parameters are 0.625219 and -0.431547, and the error is 0.800328
# parameters are 0.488406 and -0.336866, and the error is 0.625142
# parameters are 0.381541 and -0.262909, and the error is 0.488302
# parameters are 0.298068 and -0.205141, and the error is 0.381416
# parameters are 0.232867 and -0.160018, and the error is 0.297926
# parameters are 0.181937 and -0.124772, and the error is 0.232712
# parameters are 0.142156 and -0.097241, and the error is 0.181773
# parameters are 0.111083 and -0.075737, and the error is 0.141984
# parameters are 0.086811 and -0.058940, and the error is 0.110905
# parameters are 0.067853 and -0.045819, and the error is 0.086628
# parameters are 0.053044 and -0.035571, and the error is 0.067666
# parameters are 0.041477 and -0.027566, and the error is 0.052854
# parameters are 0.032442 and -0.021313, and the error is 0.041285
# parameters are 0.025384 and -0.016429, and the error is 0.032248
# parameters are 0.019871 and -0.012614, and the error is 0.025189
# parameters are 0.015565 and -0.009634, and the error is 0.019675
# parameters are 0.012202 and -0.007306, and the error is 0.015368
# parameters are 0.009575 and -0.005488, and the error is 0.012004
# parameters are 0.007523 and -0.004068, and the error is 0.009377
# parameters are 0.005920 and -0.002958, and the error is 0.007324
# parameters are 0.004668 and -0.002092, and the error is 0.005721
# parameters are 0.003690 and -0.001415, and the error is 0.004469
# parameters are 0.002926 and -0.000887, and the error is 0.003491
# parameters are 0.002329 and -0.000474, and the error is 0.002726
# parameters are 0.001863 and -0.000151, and the error is 0.002130
# parameters are 0.001499 and 0.000101, and the error is 0.001663
# parameters are 0.001215 and 0.000298, and the error is 0.001299
# parameters are 0.000993 and 0.000451, and the error is 0.001015
# parameters are 0.000819 and 0.000572, and the error is 0.000793
# parameters are 0.000684 and 0.000665, and the error is 0.000619
# parameters are 0.000578 and 0.000739, and the error is 0.000484
# parameters are 0.000495 and 0.000796, and the error is 0.000378
# parameters are 0.000430 and 0.000841, and the error is 0.000295
# parameters are 0.000380 and 0.000875, and the error is 0.000231
# parameters are 0.000341 and 0.000903, and the error is 0.000180
# parameters are 0.000310 and 0.000924, and the error is 0.000141
# parameters are 0.000286 and 0.000941, and the error is 0.000110
# parameters are 0.000267 and 0.000954, and the error is 0.000086
# parameters are 0.000252 and 0.000964, and the error is 0.000067
# parameters are 0.000241 and 0.000972, and the error is 0.000052
# parameters are 0.000232 and 0.000978, and the error is 0.000041
# parameters are 0.000225 and 0.000983, and the error is 0.000032
# parameters are 0.000219 and 0.000987, and the error is 0.000025
# parameters are 0.000215 and 0.000989, and the error is 0.000019
# parameters are 0.000212 and 0.000992, and the error is 0.000015
# parameters are 0.000209 and 0.000994, and the error is 0.000012
# parameters are 0.000207 and 0.000995, and the error is 0.000009
# parameters are 0.000206 and 0.000996, and the error is 0.000007
# parameters are 0.000204 and 0.000997, and the error is 0.000006
# parameters are 0.000203 and 0.000998, and the error is 0.000004
# parameters are 0.000203 and 0.000998, and the error is 0.000003
# parameters are 0.000202 and 0.000999, and the error is 0.000003
# parameters are 0.000202 and 0.000999, and the error is 0.000002
# parameters are 0.000201 and 0.000999, and the error is 0.000002
# parameters are 0.000201 and 0.000999, and the error is 0.000001
# parameters are 0.000201 and 0.000999, and the error is 0.000001
# parameters are 0.000201 and 0.001000, and the error is 0.000001
# 1.0
# 1.0
# parameters are 0.822210 and -0.498832, and the error is 0.924823
# parameters are 0.676029 and -0.409967, and the error is 0.760398
# parameters are 0.555838 and -0.336901, and the error is 0.625207
# parameters are 0.457015 and -0.276826, and the error is 0.514052
# parameters are 0.375763 and -0.227431, and the error is 0.422658
# parameters are 0.308956 and -0.186818, and the error is 0.347514
# parameters are 0.254026 and -0.153426, and the error is 0.285729
# parameters are 0.208863 and -0.125971, and the error is 0.234929
# parameters are 0.171729 and -0.103396, and the error is 0.193161
# parameters are 0.141198 and -0.084836, and the error is 0.158819
# parameters are 0.116094 and -0.069575, and the error is 0.130583
# parameters are 0.095454 and -0.057027, and the error is 0.107366
# parameters are 0.078483 and -0.046711, and the error is 0.088278
# parameters are 0.064529 and -0.038228, and the error is 0.072583
# parameters are 0.053057 and -0.031254, and the error is 0.059678
# parameters are 0.043624 and -0.025519, and the error is 0.049068
# parameters are 0.035868 and -0.020805, and the error is 0.040344
# parameters are 0.029491 and -0.016928, and the error is 0.033171
# parameters are 0.024248 and -0.013741, and the error is 0.027274
# parameters are 0.019937 and -0.011120, and the error is 0.022425
# parameters are 0.016392 and -0.008965, and the error is 0.018438
# parameters are 0.013478 and -0.007193, and the error is 0.015160
# parameters are 0.011082 and -0.005737, and the error is 0.012465
# parameters are 0.009111 and -0.004539, and the error is 0.010249
# parameters are 0.007491 and -0.003554, and the error is 0.008426
# parameters are 0.006160 and -0.002744, and the error is 0.006928
# parameters are 0.005064 and -0.002079, and the error is 0.005697
# parameters are 0.004164 and -0.001531, and the error is 0.004684
# parameters are 0.003424 and -0.001081, and the error is 0.003851
# parameters are 0.002815 and -0.000711, and the error is 0.003166
# parameters are 0.002315 and -0.000407, and the error is 0.002603
# parameters are 0.001903 and -0.000157, and the error is 0.002141
# parameters are 0.001565 and 0.000049, and the error is 0.001760
# parameters are 0.001287 and 0.000218, and the error is 0.001447
# parameters are 0.001058 and 0.000357, and the error is 0.001190
# parameters are 0.000870 and 0.000471, and the error is 0.000978
# parameters are 0.000715 and 0.000565, and the error is 0.000804
# parameters are 0.000588 and 0.000643, and the error is 0.000661
# parameters are 0.000483 and 0.000706, and the error is 0.000544
# parameters are 0.000397 and 0.000758, and the error is 0.000447
# parameters are 0.000327 and 0.000801, and the error is 0.000368
# parameters are 0.000269 and 0.000837, and the error is 0.000302
# parameters are 0.000221 and 0.000866, and the error is 0.000249
# parameters are 0.000182 and 0.000890, and the error is 0.000204
# parameters are 0.000149 and 0.000909, and the error is 0.000168
# parameters are 0.000123 and 0.000925, and the error is 0.000138
# parameters are 0.000101 and 0.000939, and the error is 0.000114
# parameters are 0.000083 and 0.000950, and the error is 0.000093
# parameters are 0.000068 and 0.000959, and the error is 0.000077
# parameters are 0.000056 and 0.000966, and the error is 0.000063
# parameters are 0.000046 and 0.000972, and the error is 0.000052
# parameters are 0.000038 and 0.000977, and the error is 0.000043
# parameters are 0.000031 and 0.000981, and the error is 0.000035
# parameters are 0.000026 and 0.000984, and the error is 0.000029
# parameters are 0.000021 and 0.000987, and the error is 0.000024
# parameters are 0.000017 and 0.000989, and the error is 0.000020
# parameters are 0.000014 and 0.000991, and the error is 0.000016
# parameters are 0.000012 and 0.000993, and the error is 0.000013
# parameters are 0.000010 and 0.000994, and the error is 0.000011
# parameters are 0.000008 and 0.000995, and the error is 0.000009
# parameters are 0.000007 and 0.000996, and the error is 0.000007
# parameters are 0.000005 and 0.000997, and the error is 0.000006
# parameters are 0.000004 and 0.000997, and the error is 0.000005
# parameters are 0.000004 and 0.000998, and the error is 0.000004
# parameters are 0.000003 and 0.000998, and the error is 0.000003
# parameters are 0.000002 and 0.000999, and the error is 0.000003
# parameters are 0.000002 and 0.000999, and the error is 0.000002
# parameters are 0.000002 and 0.000999, and the error is 0.000002
# parameters are 0.000001 and 0.000999, and the error is 0.000002
# parameters are 0.000001 and 0.000999, and the error is 0.000001
# parameters are 0.000001 and 0.000999, and the error is 0.000001
# parameters are 0.000001 and 0.001000, and the error is 0.000001
# 1.2
# 1.2
# parameters are 0.836844 and -0.452689, and the error is 0.839446
# parameters are 0.714065 and -0.386141, and the error is 0.716315
# parameters are 0.609296 and -0.329355, and the error is 0.611245
# parameters are 0.519895 and -0.280898, and the error is 0.521587
# parameters are 0.443607 and -0.239549, and the error is 0.445080
# parameters are 0.378509 and -0.204265, and the error is 0.379796
# parameters are 0.322959 and -0.174157, and the error is 0.324087
# parameters are 0.275558 and -0.148465, and the error is 0.276549
# parameters are 0.235110 and -0.126541, and the error is 0.235985
# parameters are 0.200594 and -0.107833, and the error is 0.201370
# parameters are 0.171141 and -0.091869, and the error is 0.171833
# parameters are 0.146009 and -0.078247, and the error is 0.146629
# parameters are 0.124563 and -0.066623, and the error is 0.125121
# parameters are 0.106263 and -0.056704, and the error is 0.106768
# parameters are 0.090647 and -0.048240, and the error is 0.091107
# parameters are 0.077321 and -0.041017, and the error is 0.077744
# parameters are 0.065950 and -0.034854, and the error is 0.066340
# parameters are 0.056247 and -0.029595, and the error is 0.056609
# parameters are 0.047967 and -0.025107, and the error is 0.048306
# parameters are 0.040902 and -0.021278, and the error is 0.041220
# parameters are 0.034873 and -0.018010, and the error is 0.035174
# parameters are 0.029729 and -0.015222, and the error is 0.030015
# parameters are 0.025339 and -0.012842, and the error is 0.025612
# parameters are 0.021593 and -0.010812, and the error is 0.021855
# parameters are 0.018396 and -0.009079, and the error is 0.018649
# parameters are 0.015668 and -0.007601, and the error is 0.015914
# parameters are 0.013341 and -0.006339, and the error is 0.013580
# parameters are 0.011355 and -0.005263, and the error is 0.011588
# parameters are 0.009660 and -0.004344, and the error is 0.009888
# parameters are 0.008214 and -0.003560, and the error is 0.008438
# parameters are 0.006979 and -0.002891, and the error is 0.007200
# parameters are 0.005926 and -0.002321, and the error is 0.006144
# parameters are 0.005028 and -0.001834, and the error is 0.005243
# parameters are 0.004261 and -0.001418, and the error is 0.004474
# parameters are 0.003607 and -0.001063, and the error is 0.003818
# parameters are 0.003048 and -0.000761, and the error is 0.003258
# parameters are 0.002572 and -0.000502, and the error is 0.002780
# parameters are 0.002165 and -0.000282, and the error is 0.002372
# parameters are 0.001818 and -0.000094, and the error is 0.002024
# parameters are 0.001522 and 0.000067, and the error is 0.001727
# parameters are 0.001270 and 0.000203, and the error is 0.001474
# parameters are 0.001054 and 0.000320, and the error is 0.001258
# parameters are 0.000870 and 0.000420, and the error is 0.001073
# parameters are 0.000713 and 0.000505, and the error is 0.000916
# parameters are 0.000579 and 0.000578, and the error is 0.000781
# parameters are 0.000465 and 0.000640, and the error is 0.000667
# parameters are 0.000367 and 0.000692, and the error is 0.000569
# parameters are 0.000284 and 0.000738, and the error is 0.000486
# parameters are 0.000213 and 0.000776, and the error is 0.000414
# parameters are 0.000153 and 0.000809, and the error is 0.000354
# parameters are 0.000101 and 0.000837, and the error is 0.000302
# parameters are 0.000057 and 0.000861, and the error is 0.000257
# parameters are 0.000019 and 0.000881, and the error is 0.000220
# parameters are -0.000013 and 0.000899, and the error is 0.000187
# parameters are -0.000040 and 0.000914, and the error is 0.000160
# parameters are -0.000064 and 0.000926, and the error is 0.000136
# parameters are -0.000084 and 0.000937, and the error is 0.000116
# parameters are -0.000101 and 0.000946, and the error is 0.000099
# parameters are -0.000115 and 0.000954, and the error is 0.000085
# parameters are -0.000128 and 0.000961, and the error is 0.000072
# parameters are -0.000138 and 0.000967, and the error is 0.000062
# parameters are -0.000147 and 0.000972, and the error is 0.000053
# parameters are -0.000155 and 0.000976, and the error is 0.000045
# parameters are -0.000162 and 0.000979, and the error is 0.000038
# parameters are -0.000167 and 0.000982, and the error is 0.000033
# parameters are -0.000172 and 0.000985, and the error is 0.000028
# parameters are -0.000176 and 0.000987, and the error is 0.000024
# parameters are -0.000180 and 0.000989, and the error is 0.000020
# parameters are -0.000183 and 0.000991, and the error is 0.000017
# parameters are -0.000185 and 0.000992, and the error is 0.000015
# parameters are -0.000187 and 0.000993, and the error is 0.000013
# parameters are -0.000189 and 0.000994, and the error is 0.000011
# parameters are -0.000191 and 0.000995, and the error is 0.000009
# parameters are -0.000192 and 0.000996, and the error is 0.000008
# parameters are -0.000193 and 0.000996, and the error is 0.000007
# parameters are -0.000194 and 0.000997, and the error is 0.000006
# parameters are -0.000195 and 0.000997, and the error is 0.000005
# parameters are -0.000196 and 0.000998, and the error is 0.000004
# parameters are -0.000196 and 0.000998, and the error is 0.000004
# parameters are -0.000197 and 0.000998, and the error is 0.000003
# parameters are -0.000197 and 0.000999, and the error is 0.000003
# parameters are -0.000198 and 0.000999, and the error is 0.000002
# parameters are -0.000198 and 0.000999, and the error is 0.000002
# parameters are -0.000198 and 0.000999, and the error is 0.000002
# parameters are -0.000199 and 0.000999, and the error is 0.000001
# parameters are -0.000199 and 0.000999, and the error is 0.000001
# parameters are -0.000199 and 0.000999, and the error is 0.000001
# 1.4
# 1.4
# parameters are 0.846701 and -0.413236, and the error is 0.766447
# parameters are 0.742726 and -0.362392, and the error is 0.672372
# parameters are 0.651513 and -0.317788, and the error is 0.589843
# parameters are 0.571496 and -0.278659, and the error is 0.517444
# parameters are 0.501300 and -0.244333, and the error is 0.453932
# parameters are 0.439720 and -0.214220, and the error is 0.398215
# parameters are 0.385699 and -0.187804, and the error is 0.349338
# parameters are 0.338308 and -0.164630, and the error is 0.306459
# parameters are 0.296734 and -0.144300, and the error is 0.268844
# parameters are 0.260263 and -0.126465, and the error is 0.235845
# parameters are 0.228269 and -0.110820, and the error is 0.206897
# parameters are 0.200201 and -0.097095, and the error is 0.181502
# parameters are 0.175579 and -0.085055, and the error is 0.159224
# parameters are 0.153979 and -0.074492, and the error is 0.139680
# parameters are 0.135030 and -0.065226, and the error is 0.122536
# parameters are 0.118407 and -0.057097, and the error is 0.107495
# parameters are 0.103825 and -0.049966, and the error is 0.094301
# parameters are 0.091032 and -0.043711, and the error is 0.082726
# parameters are 0.079809 and -0.038223, and the error is 0.072572
# parameters are 0.069964 and -0.033408, and the error is 0.063665
# parameters are 0.061328 and -0.029185, and the error is 0.055850
# parameters are 0.053751 and -0.025480, and the error is 0.048995
# parameters are 0.047104 and -0.022230, and the error is 0.042981
# parameters are 0.041274 and -0.019379, and the error is 0.037706
# parameters are 0.036158 and -0.016877, and the error is 0.033078
# parameters are 0.031671 and -0.014683, and the error is 0.029018
# parameters are 0.027735 and -0.012758, and the error is 0.025456
# parameters are 0.024281 and -0.011069, and the error is 0.022331
# parameters are 0.021252 and -0.009588, and the error is 0.019590
# parameters are 0.018594 and -0.008288, and the error is 0.017186
# parameters are 0.016263 and -0.007148, and the error is 0.015076
# parameters are 0.014218 and -0.006148, and the error is 0.013226
# parameters are 0.012423 and -0.005271, and the error is 0.011603
# parameters are 0.010849 and -0.004501, and the error is 0.010178
# parameters are 0.009469 and -0.003826, and the error is 0.008929
# parameters are 0.008257 and -0.003233, and the error is 0.007833
# parameters are 0.007195 and -0.002714, and the error is 0.006872
# parameters are 0.006263 and -0.002258, and the error is 0.006028
# parameters are 0.005445 and -0.001858, and the error is 0.005288
# parameters are 0.004727 and -0.001507, and the error is 0.004639
# parameters are 0.004098 and -0.001200, and the error is 0.004070
# parameters are 0.003546 and -0.000930, and the error is 0.003570
# parameters are 0.003062 and -0.000693, and the error is 0.003132
# parameters are 0.002637 and -0.000485, and the error is 0.002748
# parameters are 0.002264 and -0.000303, and the error is 0.002410
# parameters are 0.001937 and -0.000143, and the error is 0.002114
# parameters are 0.001650 and -0.000003, and the error is 0.001855
# parameters are 0.001399 and 0.000121, and the error is 0.001627
# parameters are 0.001178 and 0.000228, and the error is 0.001428
# parameters are 0.000984 and 0.000323, and the error is 0.001252
# parameters are 0.000814 and 0.000406, and the error is 0.001099
# parameters are 0.000665 and 0.000479, and the error is 0.000964
# parameters are 0.000534 and 0.000543, and the error is 0.000845
# parameters are 0.000420 and 0.000599, and the error is 0.000742
# parameters are 0.000319 and 0.000648, and the error is 0.000651
# parameters are 0.000231 and 0.000692, and the error is 0.000571
# parameters are 0.000153 and 0.000729, and the error is 0.000501
# parameters are 0.000085 and 0.000763, and the error is 0.000439
# parameters are 0.000026 and 0.000792, and the error is 0.000385
# parameters are -0.000026 and 0.000817, and the error is 0.000338
# parameters are -0.000072 and 0.000840, and the error is 0.000297
# parameters are -0.000112 and 0.000859, and the error is 0.000260
# parameters are -0.000148 and 0.000877, and the error is 0.000228
# parameters are -0.000179 and 0.000892, and the error is 0.000200
# parameters are -0.000206 and 0.000905, and the error is 0.000176
# parameters are -0.000230 and 0.000917, and the error is 0.000154
# parameters are -0.000251 and 0.000927, and the error is 0.000135
# parameters are -0.000269 and 0.000936, and the error is 0.000119
# parameters are -0.000285 and 0.000944, and the error is 0.000104
# parameters are -0.000299 and 0.000951, and the error is 0.000091
# parameters are -0.000312 and 0.000957, and the error is 0.000080
# parameters are -0.000322 and 0.000962, and the error is 0.000070
# parameters are -0.000332 and 0.000967, and the error is 0.000062
# parameters are -0.000340 and 0.000971, and the error is 0.000054
# parameters are -0.000348 and 0.000974, and the error is 0.000047
# parameters are -0.000354 and 0.000978, and the error is 0.000042
# parameters are -0.000360 and 0.000980, and the error is 0.000036
# parameters are -0.000365 and 0.000983, and the error is 0.000032
# parameters are -0.000369 and 0.000985, and the error is 0.000028
# parameters are -0.000373 and 0.000987, and the error is 0.000025
# parameters are -0.000376 and 0.000988, and the error is 0.000022
# parameters are -0.000379 and 0.000990, and the error is 0.000019
# parameters are -0.000382 and 0.000991, and the error is 0.000017
# parameters are -0.000384 and 0.000992, and the error is 0.000015
# parameters are -0.000386 and 0.000993, and the error is 0.000013
# parameters are -0.000388 and 0.000994, and the error is 0.000011
# parameters are -0.000389 and 0.000995, and the error is 0.000010
# parameters are -0.000390 and 0.000995, and the error is 0.000009
# parameters are -0.000392 and 0.000996, and the error is 0.000008
# parameters are -0.000393 and 0.000996, and the error is 0.000007
# parameters are -0.000394 and 0.000997, and the error is 0.000006
# parameters are -0.000394 and 0.000997, and the error is 0.000005
# parameters are -0.000395 and 0.000998, and the error is 0.000004
# parameters are -0.000396 and 0.000998, and the error is 0.000004
# parameters are -0.000396 and 0.000998, and the error is 0.000003
# parameters are -0.000397 and 0.000998, and the error is 0.000003
# parameters are -0.000397 and 0.000999, and the error is 0.000003
# parameters are -0.000397 and 0.000999, and the error is 0.000002
# parameters are -0.000398 and 0.000999, and the error is 0.000002
# parameters are -0.000398 and 0.000999, and the error is 0.000002
# parameters are -0.000398 and 0.000999, and the error is 0.000002
# parameters are -0.000398 and 0.000999, and the error is 0.000001
# parameters are -0.000399 and 0.000999, and the error is 0.000001
# parameters are -0.000399 and 0.000999, and the error is 0.000001
# parameters are -0.000399 and 0.000999, and the error is 0.000001
# 1.6
# 1.6
# parameters are 0.853343 and -0.379380, and the error is 0.703805
# parameters are 0.764516 and -0.339813, and the error is 0.630595
# parameters are 0.684928 and -0.304361, and the error is 0.565000
# parameters are 0.613619 and -0.272598, and the error is 0.506229
# parameters are 0.549728 and -0.244138, and the error is 0.453571
# parameters are 0.492483 and -0.218639, and the error is 0.406390
# parameters are 0.441192 and -0.195792, and the error is 0.364117
# parameters are 0.395237 and -0.175321, and the error is 0.326242
# parameters are 0.354062 and -0.156980, and the error is 0.292306
# parameters are 0.317170 and -0.140547, and the error is 0.261900
# parameters are 0.284115 and -0.125823, and the error is 0.234657
# parameters are 0.254499 and -0.112631, and the error is 0.210248
# parameters are 0.227963 and -0.100811, and the error is 0.188378
# parameters are 0.204188 and -0.090221, and the error is 0.168783
# parameters are 0.182886 and -0.080732, and the error is 0.151226
# parameters are 0.163800 and -0.072230, and the error is 0.135495
# parameters are 0.146699 and -0.064613, and the error is 0.121401
# parameters are 0.131377 and -0.057788, and the error is 0.108773
# parameters are 0.117649 and -0.051673, and the error is 0.097458
# parameters are 0.105348 and -0.046194, and the error is 0.087321
# parameters are 0.094327 and -0.041284, and the error is 0.078238
# parameters are 0.084453 and -0.036886, and the error is 0.070099
# parameters are 0.075606 and -0.032945, and the error is 0.062808
# parameters are 0.067679 and -0.029414, and the error is 0.056274
# parameters are 0.060577 and -0.026250, and the error is 0.050421
# parameters are 0.054213 and -0.023416, and the error is 0.045176
# parameters are 0.048511 and -0.020876, and the error is 0.040477
# parameters are 0.043403 and -0.018601, and the error is 0.036266
# parameters are 0.038826 and -0.016562, and the error is 0.032494
# parameters are 0.034724 and -0.014735, and the error is 0.029114
# parameters are 0.031050 and -0.013098, and the error is 0.026085
# parameters are 0.027758 and -0.011632, and the error is 0.023372
# parameters are 0.024808 and -0.010318, and the error is 0.020941
# parameters are 0.022165 and -0.009140, and the error is 0.018763
# parameters are 0.019797 and -0.008086, and the error is 0.016811
# parameters are 0.017675 and -0.007141, and the error is 0.015062
# parameters are 0.015774 and -0.006294, and the error is 0.013495
# parameters are 0.014071 and -0.005535, and the error is 0.012092
# parameters are 0.012545 and -0.004855, and the error is 0.010834
# parameters are 0.011178 and -0.004246, and the error is 0.009707
# parameters are 0.009952 and -0.003701, and the error is 0.008697
# parameters are 0.008855 and -0.003212, and the error is 0.007792
# parameters are 0.007871 and -0.002773, and the error is 0.006982
# parameters are 0.006990 and -0.002381, and the error is 0.006256
# parameters are 0.006201 and -0.002029, and the error is 0.005605
# parameters are 0.005493 and -0.001714, and the error is 0.005022
# parameters are 0.004859 and -0.001432, and the error is 0.004500
# parameters are 0.004292 and -0.001179, and the error is 0.004031
# parameters are 0.003783 and -0.000952, and the error is 0.003612
# parameters are 0.003327 and -0.000749, and the error is 0.003236
# parameters are 0.002918 and -0.000567, and the error is 0.002900
# parameters are 0.002552 and -0.000404, and the error is 0.002598
# parameters are 0.002224 and -0.000258, and the error is 0.002328
# parameters are 0.001931 and -0.000127, and the error is 0.002086
# parameters are 0.001667 and -0.000010, and the error is 0.001869
# parameters are 0.001432 and 0.000095, and the error is 0.001674
# parameters are 0.001220 and 0.000189, and the error is 0.001500
# parameters are 0.001031 and 0.000274, and the error is 0.001344
# parameters are 0.000861 and 0.000349, and the error is 0.001204
# parameters are 0.000709 and 0.000417, and the error is 0.001079
# parameters are 0.000573 and 0.000477, and the error is 0.000967
# parameters are 0.000451 and 0.000532, and the error is 0.000866
# parameters are 0.000342 and 0.000581, and the error is 0.000776
# parameters are 0.000244 and 0.000624, and the error is 0.000695
# parameters are 0.000156 and 0.000663, and the error is 0.000623
# parameters are 0.000077 and 0.000698, and the error is 0.000558
# parameters are 0.000007 and 0.000730, and the error is 0.000500
# parameters are -0.000056 and 0.000758, and the error is 0.000448
# parameters are -0.000113 and 0.000783, and the error is 0.000402
# parameters are -0.000163 and 0.000806, and the error is 0.000360
# parameters are -0.000209 and 0.000826, and the error is 0.000322
# parameters are -0.000250 and 0.000844, and the error is 0.000289
# parameters are -0.000286 and 0.000860, and the error is 0.000259
# parameters are -0.000319 and 0.000875, and the error is 0.000232
# parameters are -0.000348 and 0.000888, and the error is 0.000208
# parameters are -0.000374 and 0.000899, and the error is 0.000186
# parameters are -0.000398 and 0.000910, and the error is 0.000167
# parameters are -0.000419 and 0.000919, and the error is 0.000149
# parameters are -0.000438 and 0.000928, and the error is 0.000134
# parameters are -0.000454 and 0.000935, and the error is 0.000120
# parameters are -0.000470 and 0.000942, and the error is 0.000107
# parameters are -0.000483 and 0.000948, and the error is 0.000096
# parameters are -0.000495 and 0.000953, and the error is 0.000086
# parameters are -0.000506 and 0.000958, and the error is 0.000077
# parameters are -0.000516 and 0.000963, and the error is 0.000069
# parameters are -0.000525 and 0.000966, and the error is 0.000062
# parameters are -0.000533 and 0.000970, and the error is 0.000056
# parameters are -0.000540 and 0.000973, and the error is 0.000050
# parameters are -0.000546 and 0.000976, and the error is 0.000045
# parameters are -0.000551 and 0.000978, and the error is 0.000040
# parameters are -0.000557 and 0.000981, and the error is 0.000036
# parameters are -0.000561 and 0.000983, and the error is 0.000032
# parameters are -0.000565 and 0.000984, and the error is 0.000029
# parameters are -0.000569 and 0.000986, and the error is 0.000026
# parameters are -0.000572 and 0.000988, and the error is 0.000023
# parameters are -0.000575 and 0.000989, and the error is 0.000021
# parameters are -0.000578 and 0.000990, and the error is 0.000019
# parameters are -0.000580 and 0.000991, and the error is 0.000017
# parameters are -0.000582 and 0.000992, and the error is 0.000015
# parameters are -0.000584 and 0.000993, and the error is 0.000013
# parameters are -0.000586 and 0.000994, and the error is 0.000012
# parameters are -0.000587 and 0.000994, and the error is 0.000011
# parameters are -0.000588 and 0.000995, and the error is 0.000010
# parameters are -0.000590 and 0.000995, and the error is 0.000009
# parameters are -0.000591 and 0.000996, and the error is 0.000008
# parameters are -0.000592 and 0.000996, and the error is 0.000007
# parameters are -0.000593 and 0.000997, and the error is 0.000006
# parameters are -0.000593 and 0.000997, and the error is 0.000006
# parameters are -0.000594 and 0.000997, and the error is 0.000005
# parameters are -0.000595 and 0.000998, and the error is 0.000004
# parameters are -0.000595 and 0.000998, and the error is 0.000004
# parameters are -0.000596 and 0.000998, and the error is 0.000004
# parameters are -0.000596 and 0.000998, and the error is 0.000003
# parameters are -0.000597 and 0.000998, and the error is 0.000003
# parameters are -0.000597 and 0.000999, and the error is 0.000003
# parameters are -0.000597 and 0.000999, and the error is 0.000002
# parameters are -0.000597 and 0.000999, and the error is 0.000002
# parameters are -0.000598 and 0.000999, and the error is 0.000002
# parameters are -0.000598 and 0.000999, and the error is 0.000002
# parameters are -0.000598 and 0.000999, and the error is 0.000001
# parameters are -0.000598 and 0.000999, and the error is 0.000001
# parameters are -0.000599 and 0.000999, and the error is 0.000001
# parameters are -0.000599 and 0.000999, and the error is 0.000001
# parameters are -0.000599 and 0.000999, and the error is 0.000001
# 1.8
# 1.8
# parameters are 0.857788 and -0.350165, and the error is 0.649749
# parameters are 0.781242 and -0.318857, and the error is 0.591821
# parameters are 0.711520 and -0.290341, and the error is 0.539058
# parameters are 0.648014 and -0.264367, and the error is 0.490999
# parameters are 0.590170 and -0.240708, and the error is 0.447225
# parameters are 0.537483 and -0.219159, and the error is 0.407353
# parameters are 0.489493 and -0.199531, and the error is 0.371036
# parameters are 0.445781 and -0.181653, and the error is 0.337957
# parameters are 0.405967 and -0.165369, and the error is 0.307827
# parameters are 0.369702 and -0.150536, and the error is 0.280383
# parameters are 0.336671 and -0.137026, and the error is 0.255386
# parameters are 0.306584 and -0.124721, and the error is 0.232617
# parameters are 0.279179 and -0.113512, and the error is 0.211878
# parameters are 0.254218 and -0.103303, and the error is 0.192989
# parameters are 0.231482 and -0.094004, and the error is 0.175783
# parameters are 0.210774 and -0.085534, and the error is 0.160111
# parameters are 0.191911 and -0.077819, and the error is 0.145837
# parameters are 0.174730 and -0.070792, and the error is 0.132835
# parameters are 0.159081 and -0.064392, and the error is 0.120992
# parameters are 0.144827 and -0.058562, and the error is 0.110205
# parameters are 0.131844 and -0.053252, and the error is 0.100380
# parameters are 0.120018 and -0.048415, and the error is 0.091431
# parameters are 0.109247 and -0.044009, and the error is 0.083279
# parameters are 0.099436 and -0.039997, and the error is 0.075855
# parameters are 0.090499 and -0.036342, and the error is 0.069092
# parameters are 0.082360 and -0.033012, and the error is 0.062932
# parameters are 0.074946 and -0.029980, and the error is 0.057322
# parameters are 0.068193 and -0.027218, and the error is 0.052211
# parameters are 0.062042 and -0.024702, and the error is 0.047556
# parameters are 0.056439 and -0.022411, and the error is 0.043317
# parameters are 0.051336 and -0.020324, and the error is 0.039455
# parameters are 0.046688 and -0.018423, and the error is 0.035937
# parameters are 0.042454 and -0.016691, and the error is 0.032733
# parameters are 0.038598 and -0.015114, and the error is 0.029815
# parameters are 0.035085 and -0.013677, and the error is 0.027157
# parameters are 0.031886 and -0.012369, and the error is 0.024736
# parameters are 0.028972 and -0.011177, and the error is 0.022530
# parameters are 0.026318 and -0.010091, and the error is 0.020522
# parameters are 0.023900 and -0.009102, and the error is 0.018692
# parameters are 0.021698 and -0.008202, and the error is 0.017026
# parameters are 0.019692 and -0.007381, and the error is 0.015508
# parameters are 0.017865 and -0.006634, and the error is 0.014125
# parameters are 0.016201 and -0.005954, and the error is 0.012866
# parameters are 0.014685 and -0.005334, and the error is 0.011719
# parameters are 0.013305 and -0.004769, and the error is 0.010674
# parameters are 0.012047 and -0.004255, and the error is 0.009722
# parameters are 0.010902 and -0.003786, and the error is 0.008856
# parameters are 0.009859 and -0.003359, and the error is 0.008066
# parameters are 0.008908 and -0.002971, and the error is 0.007347
# parameters are 0.008043 and -0.002617, and the error is 0.006692
# parameters are 0.007255 and -0.002294, and the error is 0.006095
# parameters are 0.006536 and -0.002001, and the error is 0.005552
# parameters are 0.005882 and -0.001733, and the error is 0.005057
# parameters are 0.005287 and -0.001489, and the error is 0.004606
# parameters are 0.004744 and -0.001267, and the error is 0.004195
# parameters are 0.004250 and -0.001065, and the error is 0.003821
# parameters are 0.003800 and -0.000881, and the error is 0.003481
# parameters are 0.003389 and -0.000713, and the error is 0.003170
# parameters are 0.003016 and -0.000561, and the error is 0.002888
# parameters are 0.002676 and -0.000422, and the error is 0.002630
# parameters are 0.002366 and -0.000295, and the error is 0.002396
# parameters are 0.002084 and -0.000179, and the error is 0.002182
# parameters are 0.001827 and -0.000074, and the error is 0.001988
# parameters are 0.001592 and 0.000022, and the error is 0.001810
# parameters are 0.001379 and 0.000109, and the error is 0.001649
# parameters are 0.001185 and 0.000188, and the error is 0.001502
# parameters are 0.001008 and 0.000261, and the error is 0.001368
# parameters are 0.000847 and 0.000327, and the error is 0.001246
# parameters are 0.000700 and 0.000387, and the error is 0.001135
# parameters are 0.000566 and 0.000441, and the error is 0.001034
# parameters are 0.000444 and 0.000491, and the error is 0.000942
# parameters are 0.000333 and 0.000536, and the error is 0.000858
# parameters are 0.000232 and 0.000578, and the error is 0.000781
# parameters are 0.000140 and 0.000615, and the error is 0.000712
# parameters are 0.000056 and 0.000650, and the error is 0.000648
# parameters are -0.000020 and 0.000681, and the error is 0.000590
# parameters are -0.000089 and 0.000709, and the error is 0.000538
# parameters are -0.000153 and 0.000735, and the error is 0.000490
# parameters are -0.000210 and 0.000759, and the error is 0.000446
# parameters are -0.000263 and 0.000780, and the error is 0.000406
# parameters are -0.000311 and 0.000800, and the error is 0.000370
# parameters are -0.000355 and 0.000818, and the error is 0.000337
# parameters are -0.000394 and 0.000834, and the error is 0.000307
# parameters are -0.000430 and 0.000849, and the error is 0.000280
# parameters are -0.000463 and 0.000862, and the error is 0.000255
# parameters are -0.000493 and 0.000875, and the error is 0.000232
# parameters are -0.000521 and 0.000886, and the error is 0.000211
# parameters are -0.000546 and 0.000896, and the error is 0.000193
# parameters are -0.000568 and 0.000905, and the error is 0.000175
# parameters are -0.000589 and 0.000914, and the error is 0.000160
# parameters are -0.000608 and 0.000921, and the error is 0.000145
# parameters are -0.000625 and 0.000928, and the error is 0.000133
# parameters are -0.000641 and 0.000935, and the error is 0.000121
# parameters are -0.000655 and 0.000941, and the error is 0.000110
# parameters are -0.000668 and 0.000946, and the error is 0.000100
# parameters are -0.000679 and 0.000951, and the error is 0.000091
# parameters are -0.000690 and 0.000955, and the error is 0.000083
# parameters are -0.000700 and 0.000959, and the error is 0.000076
# parameters are -0.000709 and 0.000963, and the error is 0.000069
# parameters are -0.000717 and 0.000966, and the error is 0.000063
# parameters are -0.000724 and 0.000969, and the error is 0.000057
# parameters are -0.000731 and 0.000972, and the error is 0.000052
# parameters are -0.000737 and 0.000974, and the error is 0.000047
# parameters are -0.000743 and 0.000977, and the error is 0.000043
# parameters are -0.000748 and 0.000979, and the error is 0.000039
# parameters are -0.000753 and 0.000981, and the error is 0.000036
# parameters are -0.000757 and 0.000982, and the error is 0.000033
# parameters are -0.000761 and 0.000984, and the error is 0.000030
# parameters are -0.000764 and 0.000985, and the error is 0.000027
# parameters are -0.000767 and 0.000987, and the error is 0.000025
# parameters are -0.000770 and 0.000988, and the error is 0.000022
# parameters are -0.000773 and 0.000989, and the error is 0.000020
# parameters are -0.000775 and 0.000990, and the error is 0.000019
# parameters are -0.000778 and 0.000991, and the error is 0.000017
# parameters are -0.000780 and 0.000992, and the error is 0.000015
# parameters are -0.000781 and 0.000992, and the error is 0.000014
# parameters are -0.000783 and 0.000993, and the error is 0.000013
# parameters are -0.000785 and 0.000994, and the error is 0.000012
# parameters are -0.000786 and 0.000994, and the error is 0.000011
# parameters are -0.000787 and 0.000995, and the error is 0.000010
# parameters are -0.000788 and 0.000995, and the error is 0.000009
# parameters are -0.000789 and 0.000996, and the error is 0.000008
# parameters are -0.000790 and 0.000996, and the error is 0.000007
# parameters are -0.000791 and 0.000996, and the error is 0.000007
# parameters are -0.000792 and 0.000997, and the error is 0.000006
# parameters are -0.000793 and 0.000997, and the error is 0.000006
# parameters are -0.000793 and 0.000997, and the error is 0.000005
# parameters are -0.000794 and 0.000998, and the error is 0.000005
# parameters are -0.000794 and 0.000998, and the error is 0.000004
# parameters are -0.000795 and 0.000998, and the error is 0.000004
# parameters are -0.000795 and 0.000998, and the error is 0.000003
# parameters are -0.000796 and 0.000998, and the error is 0.000003
# parameters are -0.000796 and 0.000998, and the error is 0.000003
# parameters are -0.000797 and 0.000999, and the error is 0.000003
# parameters are -0.000797 and 0.000999, and the error is 0.000002
# parameters are -0.000797 and 0.000999, and the error is 0.000002
# parameters are -0.000797 and 0.000999, and the error is 0.000002
# parameters are -0.000798 and 0.000999, and the error is 0.000002
# parameters are -0.000798 and 0.000999, and the error is 0.000002
# parameters are -0.000798 and 0.000999, and the error is 0.000001
# parameters are -0.000798 and 0.000999, and the error is 0.000001
# parameters are -0.000798 and 0.000999, and the error is 0.000001
# parameters are -0.000799 and 0.000999, and the error is 0.000001
# parameters are -0.000799 and 0.000999, and the error is 0.000001
# parameters are -0.000799 and 0.000999, and the error is 0.000001

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
slope_k = []
sin_k = []
check_k = []
for i in range(len(para_set)):
    k = para_set[i]
    sin_k.append(np.log((1-5/(9 * k**2 + 12 * k + 9))**(1/2)))
    err = err_trajs[i]
    err_log = np.log(np.array(err)/1.9110546642)
    err_log = err_log.reshape(-1, 1)
    reg = LinearRegression().fit(np.reshape(2*np.arange(len(err_log))-1,(-1, 1)), err_log)
    slope_k.append(reg.coef_[0][0])
#     check_k.append(slope_k[-1]/sin_k[-1])

# %%
diff_u = model2.data_y - model2.data_x
mu1_pred, y1 = Hybrid_compute_linear_weight(diff_u, model2.data_lace_1)
err = np.linalg.norm(diff_u - y1, ord=np.inf)

# %%
k_axis = np.arange(-2,2.01,0.01)

# %%
import matplotlib.pyplot as plt

font_size = 18
# Define thicker line width
line_width = 1.5

# Set the figure size with height:width ratio of 1:2
plt.figure(dpi=100, figsize=(8,6))
plt.tick_params(labelsize=font_size)

plt.plot(k_axis, np.log((1-5/(9 * k_axis**2 + 12 * k_axis + 9))**(1/2)), color=color_dict_compare['ref'], markevery=10, linestyle='-', linewidth=line_width, label = 'reference')
plt.scatter(para_set, slope_k, color=color_dict_compare['compare1'], marker = 'x', linewidth=line_width+1,label = 'experiment')
plt.xlabel('parameter ν',fontsize = font_size)
plt.ylabel('slope',fontsize=font_size)
plt.ylim(-4, plt.ylim()[1])
plt.legend(fontsize=font_size)
plt.show()

# %%
para_set = [-4, -2, 0, 2, 4]
err_trajs = []
for para in para_set:
    print(para)
    err = model2.testing(para, error_bound)
    err_trajs.append(err)
# Out:
# -4
# -4
# parameters are 0.698914 and 0.207863, and the error is 0.383551
# parameters are 0.664595 and 0.197632, and the error is 0.364582
# parameters are 0.631974 and 0.187908, and the error is 0.346551
# parameters are 0.600966 and 0.178664, and the error is 0.329412
# parameters are 0.571492 and 0.169877, and the error is 0.313121
# parameters are 0.543476 and 0.161525, and the error is 0.297635
# parameters are 0.516845 and 0.153586, and the error is 0.282915
# parameters are 0.491531 and 0.146040, and the error is 0.268923
# parameters are 0.467469 and 0.138867, and the error is 0.255623
# parameters are 0.444597 and 0.132048, and the error is 0.242981
# parameters are 0.422856 and 0.125567, and the error is 0.230964
# parameters are 0.402190 and 0.119407, and the error is 0.219541
# parameters are 0.382547 and 0.113551, and the error is 0.208684
# parameters are 0.363875 and 0.107984, and the error is 0.198363
# parameters are 0.346126 and 0.102693, and the error is 0.188553
# parameters are 0.329255 and 0.097664, and the error is 0.179227
# parameters are 0.313219 and 0.092883, and the error is 0.170364
# parameters are 0.297975 and 0.088339, and the error is 0.161938
# parameters are 0.283486 and 0.084020, and the error is 0.153929
# parameters are 0.269713 and 0.079914, and the error is 0.146316
# parameters are 0.256621 and 0.076011, and the error is 0.139080
# parameters are 0.244177 and 0.072301, and the error is 0.132202
# parameters are 0.232348 and 0.068775, and the error is 0.125664
# parameters are 0.221104 and 0.065423, and the error is 0.119449
# parameters are 0.210417 and 0.062237, and the error is 0.113541
# parameters are 0.200257 and 0.059208, and the error is 0.107926
# parameters are 0.190601 and 0.056330, and the error is 0.102588
# parameters are 0.181422 and 0.053593, and the error is 0.097515
# parameters are 0.172696 and 0.050992, and the error is 0.092692
# parameters are 0.164403 and 0.048520, and the error is 0.088108
# parameters are 0.156519 and 0.046170, and the error is 0.083750
# parameters are 0.149026 and 0.043936, and the error is 0.079608
# parameters are 0.141903 and 0.041812, and the error is 0.075671
# parameters are 0.135132 and 0.039794, and the error is 0.071929
# parameters are 0.128696 and 0.037875, and the error is 0.068371
# parameters are 0.122579 and 0.036051, and the error is 0.064990
# parameters are 0.116764 and 0.034318, and the error is 0.061776
# parameters are 0.111236 and 0.032670, and the error is 0.058721
# parameters are 0.105982 and 0.031104, and the error is 0.055816
# parameters are 0.100988 and 0.029615, and the error is 0.053056
# parameters are 0.096241 and 0.028200, and the error is 0.050432
# parameters are 0.091728 and 0.026855, and the error is 0.047938
# parameters are 0.087439 and 0.025576, and the error is 0.045567
# parameters are 0.083362 and 0.024361, and the error is 0.043313
# parameters are 0.079486 and 0.023205, and the error is 0.041171
# parameters are 0.075803 and 0.022107, and the error is 0.039135
# parameters are 0.072301 and 0.021063, and the error is 0.037200
# parameters are 0.068973 and 0.020071, and the error is 0.035360
# parameters are 0.065809 and 0.019128, and the error is 0.033611
# parameters are 0.062801 and 0.018231, and the error is 0.031949
# parameters are 0.059943 and 0.017379, and the error is 0.030369
# parameters are 0.057225 and 0.016569, and the error is 0.028867
# parameters are 0.054643 and 0.015799, and the error is 0.027439
# parameters are 0.052187 and 0.015067, and the error is 0.026082
# parameters are 0.049854 and 0.014371, and the error is 0.024792
# parameters are 0.047635 and 0.013710, and the error is 0.023566
# parameters are 0.045527 and 0.013081, and the error is 0.022401
# parameters are 0.043522 and 0.012484, and the error is 0.021293
# parameters are 0.041617 and 0.011916, and the error is 0.020240
# parameters are 0.039806 and 0.011376, and the error is 0.019239
# parameters are 0.038085 and 0.010863, and the error is 0.018287
# parameters are 0.036449 and 0.010375, and the error is 0.017383
# parameters are 0.034893 and 0.009912, and the error is 0.016523
# parameters are 0.033415 and 0.009471, and the error is 0.015706
# parameters are 0.032010 and 0.009052, and the error is 0.014929
# parameters are 0.030674 and 0.008654, and the error is 0.014191
# parameters are 0.029404 and 0.008275, and the error is 0.013489
# parameters are 0.028197 and 0.007915, and the error is 0.012822
# parameters are 0.027050 and 0.007573, and the error is 0.012188
# parameters are 0.025959 and 0.007248, and the error is 0.011585
# parameters are 0.024923 and 0.006939, and the error is 0.011012
# parameters are 0.023938 and 0.006645, and the error is 0.010467
# parameters are 0.023001 and 0.006366, and the error is 0.009950
# parameters are 0.022111 and 0.006101, and the error is 0.009458
# parameters are 0.021264 and 0.005849, and the error is 0.008990
# parameters are 0.020460 and 0.005609, and the error is 0.008545
# parameters are 0.019695 and 0.005381, and the error is 0.008123
# parameters are 0.018969 and 0.005164, and the error is 0.007721
# parameters are 0.018278 and 0.004958, and the error is 0.007339
# parameters are 0.017621 and 0.004763, and the error is 0.006976
# parameters are 0.016997 and 0.004576, and the error is 0.006631
# parameters are 0.016404 and 0.004400, and the error is 0.006303
# parameters are 0.015840 and 0.004231, and the error is 0.005991
# parameters are 0.015304 and 0.004072, and the error is 0.005695
# parameters are 0.014794 and 0.003920, and the error is 0.005414
# parameters are 0.014310 and 0.003775, and the error is 0.005146
# parameters are 0.013849 and 0.003638, and the error is 0.004891
# parameters are 0.013412 and 0.003508, and the error is 0.004649
# parameters are 0.012996 and 0.003384, and the error is 0.004419
# parameters are 0.012600 and 0.003266, and the error is 0.004201
# parameters are 0.012224 and 0.003154, and the error is 0.003993
# parameters are 0.011867 and 0.003047, and the error is 0.003796
# parameters are 0.011527 and 0.002946, and the error is 0.003608
# parameters are 0.011205 and 0.002850, and the error is 0.003429
# parameters are 0.010898 and 0.002758, and the error is 0.003260
# parameters are 0.010606 and 0.002671, and the error is 0.003099
# parameters are 0.010329 and 0.002589, and the error is 0.002945
# parameters are 0.010065 and 0.002510, and the error is 0.002800
# parameters are 0.009815 and 0.002435, and the error is 0.002661
# parameters are 0.009577 and 0.002364, and the error is 0.002530
# parameters are 0.009350 and 0.002297, and the error is 0.002405
# parameters are 0.009135 and 0.002233, and the error is 0.002286
# parameters are 0.008931 and 0.002172, and the error is 0.002173
# parameters are 0.008736 and 0.002114, and the error is 0.002065
# parameters are 0.008551 and 0.002059, and the error is 0.001963
# parameters are 0.008376 and 0.002006, and the error is 0.001866
# parameters are 0.008209 and 0.001957, and the error is 0.001774
# parameters are 0.008050 and 0.001909, and the error is 0.001686
# parameters are 0.007899 and 0.001864, and the error is 0.001603
# parameters are 0.007756 and 0.001822, and the error is 0.001523
# parameters are 0.007620 and 0.001781, and the error is 0.001448
# parameters are 0.007490 and 0.001742, and the error is 0.001376
# parameters are 0.007367 and 0.001706, and the error is 0.001308
# parameters are 0.007250 and 0.001671, and the error is 0.001244
# parameters are 0.007139 and 0.001638, and the error is 0.001182
# parameters are 0.007033 and 0.001606, and the error is 0.001124
# parameters are 0.006932 and 0.001576, and the error is 0.001068
# parameters are 0.006837 and 0.001548, and the error is 0.001015
# parameters are 0.006746 and 0.001520, and the error is 0.000965
# parameters are 0.006660 and 0.001495, and the error is 0.000917
# parameters are 0.006577 and 0.001470, and the error is 0.000872
# parameters are 0.006499 and 0.001447, and the error is 0.000829
# parameters are 0.006425 and 0.001425, and the error is 0.000788
# parameters are 0.006355 and 0.001404, and the error is 0.000749
# parameters are 0.006288 and 0.001384, and the error is 0.000712
# parameters are 0.006224 and 0.001365, and the error is 0.000677
# parameters are 0.006164 and 0.001347, and the error is 0.000643
# parameters are 0.006106 and 0.001330, and the error is 0.000611
# parameters are 0.006051 and 0.001313, and the error is 0.000581
# parameters are 0.005999 and 0.001298, and the error is 0.000552
# parameters are 0.005950 and 0.001283, and the error is 0.000525
# parameters are 0.005903 and 0.001269, and the error is 0.000499
# parameters are 0.005858 and 0.001256, and the error is 0.000474
# parameters are 0.005816 and 0.001243, and the error is 0.000451
# parameters are 0.005775 and 0.001231, and the error is 0.000429
# parameters are 0.005737 and 0.001220, and the error is 0.000407
# parameters are 0.005701 and 0.001209, and the error is 0.000387
# parameters are 0.005666 and 0.001199, and the error is 0.000368
# parameters are 0.005633 and 0.001189, and the error is 0.000350
# parameters are 0.005602 and 0.001179, and the error is 0.000333
# parameters are 0.005572 and 0.001171, and the error is 0.000316
# parameters are 0.005544 and 0.001162, and the error is 0.000301
# parameters are 0.005517 and 0.001154, and the error is 0.000286
# parameters are 0.005491 and 0.001146, and the error is 0.000272
# parameters are 0.005467 and 0.001139, and the error is 0.000258
# parameters are 0.005444 and 0.001132, and the error is 0.000245
# parameters are 0.005422 and 0.001126, and the error is 0.000233
# parameters are 0.005401 and 0.001120, and the error is 0.000222
# parameters are 0.005381 and 0.001114, and the error is 0.000211
# parameters are 0.005362 and 0.001108, and the error is 0.000200
# parameters are 0.005344 and 0.001103, and the error is 0.000190
# parameters are 0.005327 and 0.001098, and the error is 0.000181
# parameters are 0.005311 and 0.001093, and the error is 0.000172
# parameters are 0.005296 and 0.001088, and the error is 0.000164
# parameters are 0.005281 and 0.001084, and the error is 0.000155
# parameters are 0.005267 and 0.001080, and the error is 0.000148
# parameters are 0.005254 and 0.001076, and the error is 0.000140
# parameters are 0.005242 and 0.001072, and the error is 0.000133
# parameters are 0.005230 and 0.001068, and the error is 0.000127
# parameters are 0.005218 and 0.001065, and the error is 0.000121
# parameters are 0.005207 and 0.001062, and the error is 0.000115
# parameters are 0.005197 and 0.001059, and the error is 0.000109
# parameters are 0.005187 and 0.001056, and the error is 0.000104
# parameters are 0.005178 and 0.001053, and the error is 0.000098
# parameters are 0.005169 and 0.001050, and the error is 0.000094
# parameters are 0.005161 and 0.001048, and the error is 0.000089
# parameters are 0.005153 and 0.001046, and the error is 0.000085
# parameters are 0.005145 and 0.001043, and the error is 0.000080
# parameters are 0.005138 and 0.001041, and the error is 0.000076
# parameters are 0.005131 and 0.001039, and the error is 0.000073
# parameters are 0.005125 and 0.001037, and the error is 0.000069
# parameters are 0.005119 and 0.001035, and the error is 0.000066
# parameters are 0.005113 and 0.001034, and the error is 0.000062
# parameters are 0.005107 and 0.001032, and the error is 0.000059
# parameters are 0.005102 and 0.001030, and the error is 0.000056
# parameters are 0.005097 and 0.001029, and the error is 0.000054
# parameters are 0.005092 and 0.001027, and the error is 0.000051
# parameters are 0.005088 and 0.001026, and the error is 0.000048
# parameters are 0.005083 and 0.001025, and the error is 0.000046
# parameters are 0.005079 and 0.001024, and the error is 0.000044
# parameters are 0.005075 and 0.001022, and the error is 0.000042
# parameters are 0.005071 and 0.001021, and the error is 0.000040
# parameters are 0.005068 and 0.001020, and the error is 0.000038
# parameters are 0.005065 and 0.001019, and the error is 0.000036
# parameters are 0.005061 and 0.001018, and the error is 0.000034
# parameters are 0.005058 and 0.001017, and the error is 0.000032
# parameters are 0.005055 and 0.001017, and the error is 0.000031
# parameters are 0.005053 and 0.001016, and the error is 0.000029
# parameters are 0.005050 and 0.001015, and the error is 0.000028
# parameters are 0.005048 and 0.001014, and the error is 0.000026
# parameters are 0.005045 and 0.001014, and the error is 0.000025
# parameters are 0.005043 and 0.001013, and the error is 0.000024
# parameters are 0.005041 and 0.001012, and the error is 0.000023
# parameters are 0.005039 and 0.001012, and the error is 0.000021
# parameters are 0.005037 and 0.001011, and the error is 0.000020
# parameters are 0.005035 and 0.001010, and the error is 0.000019
# parameters are 0.005033 and 0.001010, and the error is 0.000018
# parameters are 0.005032 and 0.001009, and the error is 0.000018
# parameters are 0.005030 and 0.001009, and the error is 0.000017
# parameters are 0.005029 and 0.001009, and the error is 0.000016
# parameters are 0.005027 and 0.001008, and the error is 0.000015
# parameters are 0.005026 and 0.001008, and the error is 0.000014
# parameters are 0.005025 and 0.001007, and the error is 0.000014
# parameters are 0.005023 and 0.001007, and the error is 0.000013
# parameters are 0.005022 and 0.001007, and the error is 0.000012
# parameters are 0.005021 and 0.001006, and the error is 0.000012
# parameters are 0.005020 and 0.001006, and the error is 0.000011
# parameters are 0.005019 and 0.001006, and the error is 0.000011
# parameters are 0.005018 and 0.001005, and the error is 0.000010
# parameters are 0.005017 and 0.001005, and the error is 0.000010
# parameters are 0.005016 and 0.001005, and the error is 0.000009
# parameters are 0.005016 and 0.001005, and the error is 0.000009
# parameters are 0.005015 and 0.001004, and the error is 0.000008
# parameters are 0.005014 and 0.001004, and the error is 0.000008
# parameters are 0.005013 and 0.001004, and the error is 0.000007
# parameters are 0.005013 and 0.001004, and the error is 0.000007
# parameters are 0.005012 and 0.001004, and the error is 0.000007
# parameters are 0.005012 and 0.001003, and the error is 0.000006
# parameters are 0.005011 and 0.001003, and the error is 0.000006
# parameters are 0.005010 and 0.001003, and the error is 0.000006
# parameters are 0.005010 and 0.001003, and the error is 0.000005
# parameters are 0.005009 and 0.001003, and the error is 0.000005
# parameters are 0.005009 and 0.001003, and the error is 0.000005
# parameters are 0.005008 and 0.001003, and the error is 0.000005
# parameters are 0.005008 and 0.001002, and the error is 0.000004
# parameters are 0.005008 and 0.001002, and the error is 0.000004
# parameters are 0.005007 and 0.001002, and the error is 0.000004
# parameters are 0.005007 and 0.001002, and the error is 0.000004
# parameters are 0.005007 and 0.001002, and the error is 0.000004
# parameters are 0.005006 and 0.001002, and the error is 0.000003
# parameters are 0.005006 and 0.001002, and the error is 0.000003
# parameters are 0.005006 and 0.001002, and the error is 0.000003
# parameters are 0.005005 and 0.001002, and the error is 0.000003
# parameters are 0.005005 and 0.001002, and the error is 0.000003
# parameters are 0.005005 and 0.001001, and the error is 0.000003
# parameters are 0.005005 and 0.001001, and the error is 0.000003
# parameters are 0.005004 and 0.001001, and the error is 0.000002
# parameters are 0.005004 and 0.001001, and the error is 0.000002
# parameters are 0.005004 and 0.001001, and the error is 0.000002
# parameters are 0.005004 and 0.001001, and the error is 0.000002
# parameters are 0.005004 and 0.001001, and the error is 0.000002
# parameters are 0.005003 and 0.001001, and the error is 0.000002
# parameters are 0.005003 and 0.001001, and the error is 0.000002
# parameters are 0.005003 and 0.001001, and the error is 0.000002
# parameters are 0.005003 and 0.001001, and the error is 0.000002
# parameters are 0.005003 and 0.001001, and the error is 0.000002
# parameters are 0.005003 and 0.001001, and the error is 0.000001
# parameters are 0.005003 and 0.001001, and the error is 0.000001
# parameters are 0.005002 and 0.001001, and the error is 0.000001
# parameters are 0.005002 and 0.001001, and the error is 0.000001
# parameters are 0.005002 and 0.001001, and the error is 0.000001
# parameters are 0.005002 and 0.001001, and the error is 0.000001
# parameters are 0.005002 and 0.001001, and the error is 0.000001
# parameters are 0.005002 and 0.001001, and the error is 0.000001
# parameters are 0.005002 and 0.001001, and the error is 0.000001
# -2
# -2
# parameters are 0.460308 and 0.338631, and the error is 0.626012
# parameters are 0.349675 and 0.256951, and the error is 0.474566
# parameters are 0.265806 and 0.195030, and the error is 0.359758
# parameters are 0.202228 and 0.148090, and the error is 0.272724
# parameters are 0.154030 and 0.112506, and the error is 0.206746
# parameters are 0.117493 and 0.085530, and the error is 0.156730
# parameters are 0.089794 and 0.065080, and the error is 0.118813
# parameters are 0.068797 and 0.049578, and the error is 0.090070
# parameters are 0.052879 and 0.037826, and the error is 0.068280
# parameters are 0.040812 and 0.028917, and the error is 0.051761
# parameters are 0.031665 and 0.022163, and the error is 0.039239
# parameters are 0.024730 and 0.017043, and the error is 0.029746
# parameters are 0.019473 and 0.013162, and the error is 0.022550
# parameters are 0.015488 and 0.010220, and the error is 0.017095
# parameters are 0.012467 and 0.007989, and the error is 0.012959
# parameters are 0.010177 and 0.006298, and the error is 0.009824
# parameters are 0.008440 and 0.005017, and the error is 0.007447
# parameters are 0.007124 and 0.004045, and the error is 0.005646
# parameters are 0.006126 and 0.003308, and the error is 0.004280
# parameters are 0.005370 and 0.002750, and the error is 0.003244
# parameters are 0.004797 and 0.002327, and the error is 0.002460
# parameters are 0.004362 and 0.002006, and the error is 0.001865
# parameters are 0.004033 and 0.001762, and the error is 0.001413
# parameters are 0.003783 and 0.001578, and the error is 0.001072
# parameters are 0.003593 and 0.001438, and the error is 0.000812
# parameters are 0.003450 and 0.001332, and the error is 0.000616
# parameters are 0.003341 and 0.001252, and the error is 0.000467
# parameters are 0.003259 and 0.001191, and the error is 0.000354
# parameters are 0.003196 and 0.001145, and the error is 0.000268
# parameters are 0.003149 and 0.001110, and the error is 0.000203
# parameters are 0.003113 and 0.001083, and the error is 0.000154
# parameters are 0.003085 and 0.001063, and the error is 0.000117
# parameters are 0.003065 and 0.001048, and the error is 0.000089
# parameters are 0.003049 and 0.001036, and the error is 0.000067
# parameters are 0.003037 and 0.001027, and the error is 0.000051
# parameters are 0.003028 and 0.001021, and the error is 0.000039
# parameters are 0.003021 and 0.001016, and the error is 0.000029
# parameters are 0.003016 and 0.001012, and the error is 0.000022
# parameters are 0.003012 and 0.001009, and the error is 0.000017
# parameters are 0.003009 and 0.001007, and the error is 0.000013
# parameters are 0.003007 and 0.001005, and the error is 0.000010
# parameters are 0.003005 and 0.001004, and the error is 0.000007
# parameters are 0.003004 and 0.001003, and the error is 0.000006
# parameters are 0.003003 and 0.001002, and the error is 0.000004
# parameters are 0.003002 and 0.001002, and the error is 0.000003
# parameters are 0.003002 and 0.001001, and the error is 0.000002
# parameters are 0.003001 and 0.001001, and the error is 0.000002
# parameters are 0.003001 and 0.001001, and the error is 0.000001
# parameters are 0.003001 and 0.001001, and the error is 0.000001
# parameters are 0.003001 and 0.001000, and the error is 0.000001
# 0
# 0
# parameters are 0.530911 and -0.819880, and the error is 1.522020
# parameters are 0.221345 and -0.340335, and the error is 0.632879
# parameters are 0.092623 and -0.140932, and the error is 0.263161
# parameters are 0.039098 and -0.058018, and the error is 0.109426
# parameters are 0.016842 and -0.023540, and the error is 0.045501
# parameters are 0.007587 and -0.009204, and the error is 0.018920
# parameters are 0.003739 and -0.003243, and the error is 0.007867
# parameters are 0.002139 and -0.000764, and the error is 0.003271
# parameters are 0.001474 and 0.000266, and the error is 0.001360
# parameters are 0.001197 and 0.000695, and the error is 0.000566
# parameters are 0.001082 and 0.000873, and the error is 0.000235
# parameters are 0.001034 and 0.000947, and the error is 0.000098
# parameters are 0.001014 and 0.000978, and the error is 0.000041
# parameters are 0.001006 and 0.000991, and the error is 0.000017
# parameters are 0.001002 and 0.000996, and the error is 0.000007
# parameters are 0.001001 and 0.000998, and the error is 0.000003
# parameters are 0.001000 and 0.000999, and the error is 0.000001
# parameters are 0.001000 and 0.001000, and the error is 0.000001
# 2
# 2
# parameters are 0.860719 and -0.324725, and the error is 0.603937
# parameters are 0.794201 and -0.299582, and the error is 0.557318
# parameters are 0.732817 and -0.276379, and the error is 0.514297
# parameters are 0.676171 and -0.254967, and the error is 0.474597
# parameters are 0.623899 and -0.235208, and the error is 0.437961
# parameters are 0.575661 and -0.216975, and the error is 0.404154
# parameters are 0.531147 and -0.200149, and the error is 0.372956
# parameters are 0.490069 and -0.184621, and the error is 0.344166
# parameters are 0.452162 and -0.170293, and the error is 0.317599
# parameters are 0.417181 and -0.157070, and the error is 0.293083
# parameters are 0.384900 and -0.144868, and the error is 0.270459
# parameters are 0.355112 and -0.133608, and the error is 0.249581
# parameters are 0.327622 and -0.123217, and the error is 0.230315
# parameters are 0.302255 and -0.113629, and the error is 0.212537
# parameters are 0.278846 and -0.104780, and the error is 0.196130
# parameters are 0.257244 and -0.096615, and the error is 0.180991
# parameters are 0.237309 and -0.089080, and the error is 0.167019
# parameters are 0.218913 and -0.082126, and the error is 0.154127
# parameters are 0.201938 and -0.075709, and the error is 0.142229
# parameters are 0.186272 and -0.069788, and the error is 0.131250
# parameters are 0.171816 and -0.064324, and the error is 0.121119
# parameters are 0.158476 and -0.059281, and the error is 0.111769
# parameters are 0.146166 and -0.054628, and the error is 0.103141
# parameters are 0.134805 and -0.050334, and the error is 0.095179
# parameters are 0.124322 and -0.046371, and the error is 0.087832
# parameters are 0.114648 and -0.042714, and the error is 0.081052
# parameters are 0.105721 and -0.039340, and the error is 0.074796
# parameters are 0.097483 and -0.036226, and the error is 0.069022
# parameters are 0.089881 and -0.033352, and the error is 0.063694
# parameters are 0.082865 and -0.030701, and the error is 0.058777
# parameters are 0.076392 and -0.028254, and the error is 0.054240
# parameters are 0.070417 and -0.025995, and the error is 0.050053
# parameters are 0.064905 and -0.023912, and the error is 0.046189
# parameters are 0.059817 and -0.021989, and the error is 0.042624
# parameters are 0.055123 and -0.020214, and the error is 0.039334
# parameters are 0.050790 and -0.018576, and the error is 0.036297
# parameters are 0.046792 and -0.017065, and the error is 0.033495
# parameters are 0.043103 and -0.015671, and the error is 0.030910
# parameters are 0.039699 and -0.014384, and the error is 0.028524
# parameters are 0.036557 and -0.013196, and the error is 0.026322
# parameters are 0.033658 and -0.012101, and the error is 0.024290
# parameters are 0.030983 and -0.011089, and the error is 0.022415
# parameters are 0.028514 and -0.010156, and the error is 0.020685
# parameters are 0.026236 and -0.009295, and the error is 0.019088
# parameters are 0.024133 and -0.008500, and the error is 0.017615
# parameters are 0.022193 and -0.007767, and the error is 0.016255
# parameters are 0.020403 and -0.007090, and the error is 0.015000
# parameters are 0.018751 and -0.006466, and the error is 0.013842
# parameters are 0.017226 and -0.005889, and the error is 0.012774
# parameters are 0.015819 and -0.005358, and the error is 0.011788
# parameters are 0.014521 and -0.004867, and the error is 0.010878
# parameters are 0.013323 and -0.004414, and the error is 0.010038
# parameters are 0.012217 and -0.003996, and the error is 0.009263
# parameters are 0.011197 and -0.003610, and the error is 0.008548
# parameters are 0.010255 and -0.003254, and the error is 0.007888
# parameters are 0.009386 and -0.002926, and the error is 0.007279
# parameters are 0.008585 and -0.002623, and the error is 0.006717
# parameters are 0.007845 and -0.002343, and the error is 0.006199
# parameters are 0.007162 and -0.002085, and the error is 0.005720
# parameters are 0.006532 and -0.001847, and the error is 0.005279
# parameters are 0.005951 and -0.001627, and the error is 0.004871
# parameters are 0.005414 and -0.001424, and the error is 0.004495
# parameters are 0.004919 and -0.001237, and the error is 0.004148
# parameters are 0.004462 and -0.001065, and the error is 0.003828
# parameters are 0.004040 and -0.000905, and the error is 0.003533
# parameters are 0.003651 and -0.000758, and the error is 0.003260
# parameters are 0.003292 and -0.000622, and the error is 0.003008
# parameters are 0.002961 and -0.000497, and the error is 0.002776
# parameters are 0.002655 and -0.000382, and the error is 0.002562
# parameters are 0.002373 and -0.000275, and the error is 0.002364
# parameters are 0.002113 and -0.000177, and the error is 0.002182
# parameters are 0.001872 and -0.000086, and the error is 0.002013
# parameters are 0.001651 and -0.000002, and the error is 0.001858
# parameters are 0.001446 and 0.000075, and the error is 0.001714
# parameters are 0.001257 and 0.000147, and the error is 0.001582
# parameters are 0.001083 and 0.000213, and the error is 0.001460
# parameters are 0.000922 and 0.000273, and the error is 0.001347
# parameters are 0.000774 and 0.000330, and the error is 0.001243
# parameters are 0.000637 and 0.000381, and the error is 0.001147
# parameters are 0.000511 and 0.000429, and the error is 0.001059
# parameters are 0.000394 and 0.000473, and the error is 0.000977
# parameters are 0.000286 and 0.000514, and the error is 0.000902
# parameters are 0.000187 and 0.000551, and the error is 0.000832
# parameters are 0.000095 and 0.000586, and the error is 0.000768
# parameters are 0.000011 and 0.000618, and the error is 0.000708
# parameters are -0.000067 and 0.000647, and the error is 0.000654
# parameters are -0.000139 and 0.000675, and the error is 0.000603
# parameters are -0.000206 and 0.000700, and the error is 0.000557
# parameters are -0.000267 and 0.000723, and the error is 0.000514
# parameters are -0.000324 and 0.000744, and the error is 0.000474
# parameters are -0.000376 and 0.000764, and the error is 0.000437
# parameters are -0.000424 and 0.000782, and the error is 0.000404
# parameters are -0.000468 and 0.000799, and the error is 0.000373
# parameters are -0.000509 and 0.000815, and the error is 0.000344
# parameters are -0.000547 and 0.000829, and the error is 0.000317
# parameters are -0.000582 and 0.000842, and the error is 0.000293
# parameters are -0.000615 and 0.000854, and the error is 0.000270
# parameters are -0.000644 and 0.000866, and the error is 0.000249
# parameters are -0.000672 and 0.000876, and the error is 0.000230
# parameters are -0.000697 and 0.000885, and the error is 0.000212
# parameters are -0.000720 and 0.000894, and the error is 0.000196
# parameters are -0.000742 and 0.000902, and the error is 0.000181
# parameters are -0.000762 and 0.000910, and the error is 0.000167
# parameters are -0.000780 and 0.000917, and the error is 0.000154
# parameters are -0.000797 and 0.000923, and the error is 0.000142
# parameters are -0.000813 and 0.000929, and the error is 0.000131
# parameters are -0.000827 and 0.000935, and the error is 0.000121
# parameters are -0.000841 and 0.000940, and the error is 0.000112
# parameters are -0.000853 and 0.000944, and the error is 0.000103
# parameters are -0.000864 and 0.000949, and the error is 0.000095
# parameters are -0.000875 and 0.000953, and the error is 0.000088
# parameters are -0.000884 and 0.000956, and the error is 0.000081
# parameters are -0.000893 and 0.000960, and the error is 0.000075
# parameters are -0.000902 and 0.000963, and the error is 0.000069
# parameters are -0.000909 and 0.000966, and the error is 0.000064
# parameters are -0.000916 and 0.000968, and the error is 0.000059
# parameters are -0.000923 and 0.000971, and the error is 0.000054
# parameters are -0.000929 and 0.000973, and the error is 0.000050
# parameters are -0.000934 and 0.000975, and the error is 0.000046
# parameters are -0.000939 and 0.000977, and the error is 0.000043
# parameters are -0.000944 and 0.000979, and the error is 0.000039
# parameters are -0.000948 and 0.000980, and the error is 0.000036
# parameters are -0.000952 and 0.000982, and the error is 0.000033
# parameters are -0.000956 and 0.000983, and the error is 0.000031
# parameters are -0.000959 and 0.000985, and the error is 0.000028
# parameters are -0.000962 and 0.000986, and the error is 0.000026
# parameters are -0.000965 and 0.000987, and the error is 0.000024
# parameters are -0.000968 and 0.000988, and the error is 0.000022
# parameters are -0.000971 and 0.000989, and the error is 0.000021
# parameters are -0.000973 and 0.000990, and the error is 0.000019
# parameters are -0.000975 and 0.000991, and the error is 0.000018
# parameters are -0.000977 and 0.000991, and the error is 0.000016
# parameters are -0.000979 and 0.000992, and the error is 0.000015
# parameters are -0.000980 and 0.000993, and the error is 0.000014
# parameters are -0.000982 and 0.000993, and the error is 0.000013
# parameters are -0.000983 and 0.000994, and the error is 0.000012
# parameters are -0.000984 and 0.000994, and the error is 0.000011
# parameters are -0.000986 and 0.000995, and the error is 0.000010
# parameters are -0.000987 and 0.000995, and the error is 0.000009
# parameters are -0.000988 and 0.000995, and the error is 0.000009
# parameters are -0.000989 and 0.000996, and the error is 0.000008
# parameters are -0.000990 and 0.000996, and the error is 0.000007
# parameters are -0.000990 and 0.000996, and the error is 0.000007
# parameters are -0.000991 and 0.000997, and the error is 0.000006
# parameters are -0.000992 and 0.000997, and the error is 0.000006
# parameters are -0.000992 and 0.000997, and the error is 0.000005
# parameters are -0.000993 and 0.000997, and the error is 0.000005
# parameters are -0.000994 and 0.000998, and the error is 0.000004
# parameters are -0.000994 and 0.000998, and the error is 0.000004
# parameters are -0.000995 and 0.000998, and the error is 0.000004
# parameters are -0.000995 and 0.000998, and the error is 0.000004
# parameters are -0.000995 and 0.000998, and the error is 0.000003
# parameters are -0.000996 and 0.000998, and the error is 0.000003
# parameters are -0.000996 and 0.000999, and the error is 0.000003
# parameters are -0.000996 and 0.000999, and the error is 0.000003
# parameters are -0.000997 and 0.000999, and the error is 0.000002
# parameters are -0.000997 and 0.000999, and the error is 0.000002
# parameters are -0.000997 and 0.000999, and the error is 0.000002
# parameters are -0.000997 and 0.000999, and the error is 0.000002
# parameters are -0.000998 and 0.000999, and the error is 0.000002
# parameters are -0.000998 and 0.000999, and the error is 0.000002
# parameters are -0.000998 and 0.000999, and the error is 0.000001
# parameters are -0.000998 and 0.000999, and the error is 0.000001
# parameters are -0.000998 and 0.000999, and the error is 0.000001
# parameters are -0.000998 and 0.000999, and the error is 0.000001
# parameters are -0.000998 and 0.000999, and the error is 0.000001
# parameters are -0.000999 and 0.000999, and the error is 0.000001
# 4
# 4
# parameters are 0.861738 and -0.185144, and the error is 0.345135
# parameters are 0.838899 and -0.180227, and the error is 0.336019
# parameters are 0.816662 and -0.175441, and the error is 0.327144
# parameters are 0.795014 and -0.170781, and the error is 0.318504
# parameters are 0.773937 and -0.166244, and the error is 0.310092
# parameters are 0.753416 and -0.161826, and the error is 0.301901
# parameters are 0.733438 and -0.157526, and the error is 0.293928
# parameters are 0.713987 and -0.153339, and the error is 0.286165
# parameters are 0.695051 and -0.149263, and the error is 0.278606
# parameters are 0.676614 and -0.145294, and the error is 0.271248
# parameters are 0.658664 and -0.141430, and the error is 0.264084
# parameters are 0.641188 and -0.137668, and the error is 0.257109
# parameters are 0.624174 and -0.134006, and the error is 0.250318
# parameters are 0.607609 and -0.130440, and the error is 0.243707
# parameters are 0.591482 and -0.126968, and the error is 0.237270
# parameters are 0.575781 and -0.123588, and the error is 0.231003
# parameters are 0.560494 and -0.120298, and the error is 0.224902
# parameters are 0.545611 and -0.117094, and the error is 0.218962
# parameters are 0.531121 and -0.113975, and the error is 0.213179
# parameters are 0.517014 and -0.110938, and the error is 0.207548
# parameters are 0.503280 and -0.107982, and the error is 0.202067
# parameters are 0.489908 and -0.105103, and the error is 0.196730
# parameters are 0.476889 and -0.102301, and the error is 0.191534
# parameters are 0.464215 and -0.099573, and the error is 0.186475
# parameters are 0.451875 and -0.096916, and the error is 0.181550
# parameters are 0.439861 and -0.094330, and the error is 0.176755
# parameters are 0.428164 and -0.091812, and the error is 0.172086
# parameters are 0.416776 and -0.089361, and the error is 0.167541
# parameters are 0.405689 and -0.086974, and the error is 0.163116
# parameters are 0.394895 and -0.084651, and the error is 0.158808
# parameters are 0.384386 and -0.082389, and the error is 0.154614
# parameters are 0.374154 and -0.080186, and the error is 0.150530
# parameters are 0.364193 and -0.078042, and the error is 0.146554
# parameters are 0.354495 and -0.075954, and the error is 0.142683
# parameters are 0.345053 and -0.073922, and the error is 0.138915
# parameters are 0.335860 and -0.071943, and the error is 0.135246
# parameters are 0.326910 and -0.070016, and the error is 0.131674
# parameters are 0.318196 and -0.068141, and the error is 0.128196
# parameters are 0.309713 and -0.066315, and the error is 0.124810
# parameters are 0.301454 and -0.064537, and the error is 0.121514
# parameters are 0.293413 and -0.062806, and the error is 0.118304
# parameters are 0.285584 and -0.061121, and the error is 0.115180
# parameters are 0.277962 and -0.059480, and the error is 0.112138
# parameters are 0.270541 and -0.057883, and the error is 0.109176
# parameters are 0.263316 and -0.056327, and the error is 0.106292
# parameters are 0.256282 and -0.054813, and the error is 0.103485
# parameters are 0.249434 and -0.053339, and the error is 0.100752
# parameters are 0.242767 and -0.051904, and the error is 0.098091
# parameters are 0.236276 and -0.050507, and the error is 0.095500
# parameters are 0.229956 and -0.049146, and the error is 0.092978
# parameters are 0.223803 and -0.047822, and the error is 0.090522
# parameters are 0.217813 and -0.046532, and the error is 0.088131
# parameters are 0.211981 and -0.045277, and the error is 0.085803
# parameters are 0.206303 and -0.044055, and the error is 0.083537
# parameters are 0.200775 and -0.042865, and the error is 0.081331
# parameters are 0.195393 and -0.041706, and the error is 0.079183
# parameters are 0.190153 and -0.040578, and the error is 0.077091
# parameters are 0.185051 and -0.039480, and the error is 0.075055
# parameters are 0.180085 and -0.038411, and the error is 0.073073
# parameters are 0.175249 and -0.037370, and the error is 0.071143
# parameters are 0.170541 and -0.036357, and the error is 0.069264
# parameters are 0.165958 and -0.035370, and the error is 0.067435
# parameters are 0.161495 and -0.034409, and the error is 0.065653
# parameters are 0.157151 and -0.033474, and the error is 0.063919
# parameters are 0.152921 and -0.032564, and the error is 0.062231
# parameters are 0.148803 and -0.031677, and the error is 0.060588
# parameters are 0.144793 and -0.030814, and the error is 0.058987
# parameters are 0.140890 and -0.029974, and the error is 0.057429
# parameters are 0.137089 and -0.029156, and the error is 0.055913
# parameters are 0.133389 and -0.028359, and the error is 0.054436
# parameters are 0.129787 and -0.027584, and the error is 0.052998
# parameters are 0.126280 and -0.026829, and the error is 0.051598
# parameters are 0.122865 and -0.026094, and the error is 0.050235
# parameters are 0.119541 and -0.025378, and the error is 0.048909
# parameters are 0.116305 and -0.024682, and the error is 0.047617
# parameters are 0.113153 and -0.024003, and the error is 0.046359
# parameters are 0.110086 and -0.023343, and the error is 0.045135
# parameters are 0.107099 and -0.022700, and the error is 0.043943
# parameters are 0.104191 and -0.022074, and the error is 0.042782
# parameters are 0.101360 and -0.021465, and the error is 0.041652
# parameters are 0.098604 and -0.020871, and the error is 0.040552
# parameters are 0.095920 and -0.020294, and the error is 0.039481
# parameters are 0.093307 and -0.019731, and the error is 0.038438
# parameters are 0.090764 and -0.019184, and the error is 0.037423
# parameters are 0.088287 and -0.018651, and the error is 0.036435
# parameters are 0.085876 and -0.018132, and the error is 0.035472
# parameters are 0.083529 and -0.017626, and the error is 0.034535
# parameters are 0.081243 and -0.017134, and the error is 0.033623
# parameters are 0.079018 and -0.016655, and the error is 0.032735
# parameters are 0.076852 and -0.016189, and the error is 0.031871
# parameters are 0.074743 and -0.015735, and the error is 0.031029
# parameters are 0.072690 and -0.015293, and the error is 0.030209
# parameters are 0.070691 and -0.014863, and the error is 0.029411
# parameters are 0.068744 and -0.014444, and the error is 0.028635
# parameters are 0.066849 and -0.014036, and the error is 0.027878
# parameters are 0.065005 and -0.013639, and the error is 0.027142
# parameters are 0.063208 and -0.013252, and the error is 0.026425
# parameters are 0.061460 and -0.012876, and the error is 0.025727
# parameters are 0.059757 and -0.012509, and the error is 0.025048
# parameters are 0.058100 and -0.012152, and the error is 0.024386
# parameters are 0.056486 and -0.011805, and the error is 0.023742
# parameters are 0.054915 and -0.011467, and the error is 0.023115
# parameters are 0.053385 and -0.011137, and the error is 0.022505
# parameters are 0.051896 and -0.010817, and the error is 0.021910
# parameters are 0.050446 and -0.010505, and the error is 0.021331
# parameters are 0.049034 and -0.010201, and the error is 0.020768
# parameters are 0.047660 and -0.009905, and the error is 0.020220
# parameters are 0.046322 and -0.009617, and the error is 0.019685
# parameters are 0.045019 and -0.009337, and the error is 0.019166
# parameters are 0.043751 and -0.009064, and the error is 0.018659
# parameters are 0.042516 and -0.008798, and the error is 0.018167
# parameters are 0.041314 and -0.008539, and the error is 0.017687
# parameters are 0.040144 and -0.008287, and the error is 0.017220
# parameters are 0.039004 and -0.008042, and the error is 0.016765
# parameters are 0.037895 and -0.007803, and the error is 0.016322
# parameters are 0.036815 and -0.007571, and the error is 0.015891
# parameters are 0.035763 and -0.007344, and the error is 0.015471
# parameters are 0.034739 and -0.007124, and the error is 0.015063
# parameters are 0.033743 and -0.006909, and the error is 0.014665
# parameters are 0.032772 and -0.006700, and the error is 0.014277
# parameters are 0.031827 and -0.006497, and the error is 0.013900
# parameters are 0.030908 and -0.006299, and the error is 0.013533
# parameters are 0.030012 and -0.006106, and the error is 0.013176
# parameters are 0.029140 and -0.005918, and the error is 0.012828
# parameters are 0.028291 and -0.005736, and the error is 0.012489
# parameters are 0.027465 and -0.005558, and the error is 0.012159
# parameters are 0.026660 and -0.005385, and the error is 0.011838
# parameters are 0.025877 and -0.005216, and the error is 0.011525
# parameters are 0.025114 and -0.005052, and the error is 0.011221
# parameters are 0.024371 and -0.004892, and the error is 0.010925
# parameters are 0.023649 and -0.004736, and the error is 0.010636
# parameters are 0.022945 and -0.004585, and the error is 0.010355
# parameters are 0.022259 and -0.004437, and the error is 0.010082
# parameters are 0.021592 and -0.004294, and the error is 0.009815
# parameters are 0.020943 and -0.004154, and the error is 0.009556
# parameters are 0.020310 and -0.004018, and the error is 0.009304
# parameters are 0.019695 and -0.003885, and the error is 0.009058
# parameters are 0.019095 and -0.003756, and the error is 0.008819
# parameters are 0.018512 and -0.003631, and the error is 0.008586
# parameters are 0.017944 and -0.003508, and the error is 0.008359
# parameters are 0.017390 and -0.003389, and the error is 0.008138
# parameters are 0.016852 and -0.003273, and the error is 0.007923
# parameters are 0.016328 and -0.003160, and the error is 0.007714
# parameters are 0.015817 and -0.003051, and the error is 0.007510
# parameters are 0.015320 and -0.002944, and the error is 0.007312
# parameters are 0.014836 and -0.002839, and the error is 0.007119
# parameters are 0.014365 and -0.002738, and the error is 0.006931
# parameters are 0.013907 and -0.002639, and the error is 0.006748
# parameters are 0.013460 and -0.002543, and the error is 0.006570
# parameters are 0.013025 and -0.002450, and the error is 0.006396
# parameters are 0.012602 and -0.002358, and the error is 0.006227
# parameters are 0.012190 and -0.002270, and the error is 0.006063
# parameters are 0.011789 and -0.002183, and the error is 0.005902
# parameters are 0.011398 and -0.002099, and the error is 0.005747
# parameters are 0.011018 and -0.002017, and the error is 0.005595
# parameters are 0.010648 and -0.001938, and the error is 0.005447
# parameters are 0.010287 and -0.001860, and the error is 0.005303
# parameters are 0.009936 and -0.001785, and the error is 0.005163
# parameters are 0.009595 and -0.001711, and the error is 0.005027
# parameters are 0.009262 and -0.001639, and the error is 0.004894
# parameters are 0.008938 and -0.001570, and the error is 0.004765
# parameters are 0.008623 and -0.001502, and the error is 0.004639
# parameters are 0.008316 and -0.001436, and the error is 0.004516
# parameters are 0.008017 and -0.001371, and the error is 0.004397
# parameters are 0.007726 and -0.001309, and the error is 0.004281
# parameters are 0.007443 and -0.001248, and the error is 0.004168
# parameters are 0.007167 and -0.001189, and the error is 0.004058
# parameters are 0.006898 and -0.001131, and the error is 0.003951
# parameters are 0.006637 and -0.001074, and the error is 0.003846
# parameters are 0.006382 and -0.001020, and the error is 0.003745
# parameters are 0.006135 and -0.000966, and the error is 0.003646
# parameters are 0.005893 and -0.000914, and the error is 0.003549
# parameters are 0.005658 and -0.000864, and the error is 0.003456
# parameters are 0.005430 and -0.000815, and the error is 0.003364
# parameters are 0.005207 and -0.000767, and the error is 0.003276
# parameters are 0.004990 and -0.000720, and the error is 0.003189
# parameters are 0.004779 and -0.000675, and the error is 0.003105
# parameters are 0.004574 and -0.000630, and the error is 0.003023
# parameters are 0.004374 and -0.000587, and the error is 0.002943
# parameters are 0.004179 and -0.000545, and the error is 0.002865
# parameters are 0.003989 and -0.000505, and the error is 0.002790
# parameters are 0.003805 and -0.000465, and the error is 0.002716
# parameters are 0.003625 and -0.000426, and the error is 0.002644
# parameters are 0.003450 and -0.000388, and the error is 0.002574
# parameters are 0.003280 and -0.000352, and the error is 0.002506
# parameters are 0.003114 and -0.000316, and the error is 0.002440
# parameters are 0.002952 and -0.000281, and the error is 0.002376
# parameters are 0.002795 and -0.000247, and the error is 0.002313
# parameters are 0.002642 and -0.000215, and the error is 0.002252
# parameters are 0.002493 and -0.000182, and the error is 0.002192
# parameters are 0.002348 and -0.000151, and the error is 0.002135
# parameters are 0.002207 and -0.000121, and the error is 0.002078
# parameters are 0.002069 and -0.000091, and the error is 0.002023
# parameters are 0.001935 and -0.000062, and the error is 0.001970
# parameters are 0.001805 and -0.000034, and the error is 0.001918
# parameters are 0.001678 and -0.000007, and the error is 0.001867
# parameters are 0.001555 and 0.000020, and the error is 0.001818
# parameters are 0.001434 and 0.000045, and the error is 0.001770
# parameters are 0.001317 and 0.000071, and the error is 0.001723
# parameters are 0.001203 and 0.000095, and the error is 0.001678
# parameters are 0.001092 and 0.000119, and the error is 0.001633
# parameters are 0.000984 and 0.000142, and the error is 0.001590
# parameters are 0.000879 and 0.000165, and the error is 0.001548
# parameters are 0.000776 and 0.000187, and the error is 0.001507
# parameters are 0.000677 and 0.000209, and the error is 0.001467
# parameters are 0.000579 and 0.000229, and the error is 0.001429
# parameters are 0.000485 and 0.000250, and the error is 0.001391
# parameters are 0.000393 and 0.000270, and the error is 0.001354
# parameters are 0.000303 and 0.000289, and the error is 0.001318
# parameters are 0.000216 and 0.000308, and the error is 0.001284
# parameters are 0.000131 and 0.000326, and the error is 0.001250
# parameters are 0.000048 and 0.000344, and the error is 0.001217
# parameters are -0.000032 and 0.000361, and the error is 0.001185
# parameters are -0.000110 and 0.000378, and the error is 0.001153
# parameters are -0.000187 and 0.000394, and the error is 0.001123
# parameters are -0.000261 and 0.000410, and the error is 0.001093
# parameters are -0.000333 and 0.000426, and the error is 0.001064
# parameters are -0.000404 and 0.000441, and the error is 0.001036
# parameters are -0.000472 and 0.000456, and the error is 0.001009
# parameters are -0.000539 and 0.000470, and the error is 0.000982
# parameters are -0.000604 and 0.000484, and the error is 0.000956
# parameters are -0.000667 and 0.000498, and the error is 0.000931
# parameters are -0.000729 and 0.000511, and the error is 0.000906
# parameters are -0.000789 and 0.000524, and the error is 0.000882
# parameters are -0.000847 and 0.000537, and the error is 0.000859
# parameters are -0.000904 and 0.000549, and the error is 0.000836
# parameters are -0.000960 and 0.000561, and the error is 0.000814
# parameters are -0.001014 and 0.000572, and the error is 0.000793
# parameters are -0.001066 and 0.000584, and the error is 0.000772
# parameters are -0.001117 and 0.000595, and the error is 0.000752
# parameters are -0.001167 and 0.000605, and the error is 0.000732
# parameters are -0.001215 and 0.000616, and the error is 0.000712
# parameters are -0.001262 and 0.000626, and the error is 0.000694
# parameters are -0.001308 and 0.000636, and the error is 0.000675
# parameters are -0.001353 and 0.000645, and the error is 0.000657
# parameters are -0.001396 and 0.000655, and the error is 0.000640
# parameters are -0.001439 and 0.000664, and the error is 0.000623
# parameters are -0.001480 and 0.000673, and the error is 0.000607
# parameters are -0.001520 and 0.000681, and the error is 0.000591
# parameters are -0.001559 and 0.000690, and the error is 0.000575
# parameters are -0.001597 and 0.000698, and the error is 0.000560
# parameters are -0.001634 and 0.000706, and the error is 0.000545
# parameters are -0.001670 and 0.000714, and the error is 0.000531
# parameters are -0.001706 and 0.000721, and the error is 0.000517
# parameters are -0.001740 and 0.000729, and the error is 0.000503
# parameters are -0.001773 and 0.000736, and the error is 0.000490
# parameters are -0.001805 and 0.000743, and the error is 0.000477
# parameters are -0.001837 and 0.000750, and the error is 0.000464
# parameters are -0.001868 and 0.000756, and the error is 0.000452
# parameters are -0.001898 and 0.000763, and the error is 0.000440
# parameters are -0.001927 and 0.000769, and the error is 0.000428
# parameters are -0.001955 and 0.000775, and the error is 0.000417
# parameters are -0.001983 and 0.000781, and the error is 0.000406
# parameters are -0.002010 and 0.000787, and the error is 0.000395
# parameters are -0.002036 and 0.000792, and the error is 0.000385
# parameters are -0.002061 and 0.000798, and the error is 0.000375
# parameters are -0.002086 and 0.000803, and the error is 0.000365
# parameters are -0.002110 and 0.000808, and the error is 0.000355
# parameters are -0.002134 and 0.000814, and the error is 0.000346
# parameters are -0.002156 and 0.000818, and the error is 0.000337
# parameters are -0.002179 and 0.000823, and the error is 0.000328
# parameters are -0.002200 and 0.000828, and the error is 0.000319
# parameters are -0.002222 and 0.000832, and the error is 0.000311
# parameters are -0.002242 and 0.000837, and the error is 0.000302
# parameters are -0.002262 and 0.000841, and the error is 0.000294
# parameters are -0.002282 and 0.000845, and the error is 0.000287
# parameters are -0.002301 and 0.000849, and the error is 0.000279
# parameters are -0.002319 and 0.000853, and the error is 0.000272
# parameters are -0.002337 and 0.000857, and the error is 0.000265
# parameters are -0.002355 and 0.000861, and the error is 0.000258
# parameters are -0.002372 and 0.000865, and the error is 0.000251
# parameters are -0.002388 and 0.000868, and the error is 0.000244
# parameters are -0.002404 and 0.000872, and the error is 0.000238
# parameters are -0.002420 and 0.000875, and the error is 0.000231
# parameters are -0.002435 and 0.000878, and the error is 0.000225
# parameters are -0.002450 and 0.000882, and the error is 0.000219
# parameters are -0.002465 and 0.000885, and the error is 0.000214
# parameters are -0.002479 and 0.000888, and the error is 0.000208
# parameters are -0.002493 and 0.000891, and the error is 0.000202
# parameters are -0.002506 and 0.000894, and the error is 0.000197
# parameters are -0.002519 and 0.000897, and the error is 0.000192
# parameters are -0.002532 and 0.000899, and the error is 0.000187
# parameters are -0.002544 and 0.000902, and the error is 0.000182
# parameters are -0.002556 and 0.000904, and the error is 0.000177
# parameters are -0.002568 and 0.000907, and the error is 0.000172
# parameters are -0.002579 and 0.000909, and the error is 0.000168
# parameters are -0.002591 and 0.000912, and the error is 0.000163
# parameters are -0.002601 and 0.000914, and the error is 0.000159
# parameters are -0.002612 and 0.000916, and the error is 0.000155
# parameters are -0.002622 and 0.000919, and the error is 0.000151
# parameters are -0.002632 and 0.000921, and the error is 0.000147
# parameters are -0.002642 and 0.000923, and the error is 0.000143
# parameters are -0.002651 and 0.000925, and the error is 0.000139
# parameters are -0.002660 and 0.000927, and the error is 0.000136
# parameters are -0.002669 and 0.000929, and the error is 0.000132
# parameters are -0.002678 and 0.000931, and the error is 0.000128
# parameters are -0.002687 and 0.000933, and the error is 0.000125
# parameters are -0.002695 and 0.000934, and the error is 0.000122
# parameters are -0.002703 and 0.000936, and the error is 0.000119
# parameters are -0.002711 and 0.000938, and the error is 0.000115
# parameters are -0.002719 and 0.000939, and the error is 0.000112
# parameters are -0.002726 and 0.000941, and the error is 0.000109
# parameters are -0.002733 and 0.000943, and the error is 0.000106
# parameters are -0.002740 and 0.000944, and the error is 0.000104
# parameters are -0.002747 and 0.000946, and the error is 0.000101
# parameters are -0.002754 and 0.000947, and the error is 0.000098
# parameters are -0.002760 and 0.000948, and the error is 0.000096
# parameters are -0.002767 and 0.000950, and the error is 0.000093
# parameters are -0.002773 and 0.000951, and the error is 0.000091
# parameters are -0.002779 and 0.000952, and the error is 0.000088
# parameters are -0.002785 and 0.000954, and the error is 0.000086
# parameters are -0.002790 and 0.000955, and the error is 0.000084
# parameters are -0.002796 and 0.000956, and the error is 0.000081
# parameters are -0.002801 and 0.000957, and the error is 0.000079
# parameters are -0.002806 and 0.000958, and the error is 0.000077
# parameters are -0.002812 and 0.000959, and the error is 0.000075
# parameters are -0.002817 and 0.000961, and the error is 0.000073
# parameters are -0.002821 and 0.000962, and the error is 0.000071
# parameters are -0.002826 and 0.000963, and the error is 0.000069
# parameters are -0.002831 and 0.000964, and the error is 0.000068
# parameters are -0.002835 and 0.000965, and the error is 0.000066
# parameters are -0.002840 and 0.000965, and the error is 0.000064
# parameters are -0.002844 and 0.000966, and the error is 0.000062
# parameters are -0.002848 and 0.000967, and the error is 0.000061
# parameters are -0.002852 and 0.000968, and the error is 0.000059
# parameters are -0.002856 and 0.000969, and the error is 0.000058
# parameters are -0.002860 and 0.000970, and the error is 0.000056
# parameters are -0.002863 and 0.000971, and the error is 0.000055
# parameters are -0.002867 and 0.000971, and the error is 0.000053
# parameters are -0.002870 and 0.000972, and the error is 0.000052
# parameters are -0.002874 and 0.000973, and the error is 0.000050
# parameters are -0.002877 and 0.000974, and the error is 0.000049
# parameters are -0.002880 and 0.000974, and the error is 0.000048
# parameters are -0.002884 and 0.000975, and the error is 0.000046
# parameters are -0.002887 and 0.000976, and the error is 0.000045
# parameters are -0.002890 and 0.000976, and the error is 0.000044
# parameters are -0.002893 and 0.000977, and the error is 0.000043
# parameters are -0.002895 and 0.000977, and the error is 0.000042
# parameters are -0.002898 and 0.000978, and the error is 0.000041
# parameters are -0.002901 and 0.000979, and the error is 0.000040
# parameters are -0.002904 and 0.000979, and the error is 0.000039
# parameters are -0.002906 and 0.000980, and the error is 0.000037
# parameters are -0.002909 and 0.000980, and the error is 0.000037
# parameters are -0.002911 and 0.000981, and the error is 0.000036
# parameters are -0.002913 and 0.000981, and the error is 0.000035
# parameters are -0.002916 and 0.000982, and the error is 0.000034
# parameters are -0.002918 and 0.000982, and the error is 0.000033
# parameters are -0.002920 and 0.000983, and the error is 0.000032
# parameters are -0.002922 and 0.000983, and the error is 0.000031
# parameters are -0.002924 and 0.000984, and the error is 0.000030
# parameters are -0.002926 and 0.000984, and the error is 0.000029
# parameters are -0.002928 and 0.000985, and the error is 0.000029
# parameters are -0.002930 and 0.000985, and the error is 0.000028
# parameters are -0.002932 and 0.000985, and the error is 0.000027
# parameters are -0.002934 and 0.000986, and the error is 0.000026
# parameters are -0.002935 and 0.000986, and the error is 0.000026
# parameters are -0.002937 and 0.000986, and the error is 0.000025
# parameters are -0.002939 and 0.000987, and the error is 0.000024
# parameters are -0.002940 and 0.000987, and the error is 0.000024
# parameters are -0.002942 and 0.000988, and the error is 0.000023
# parameters are -0.002944 and 0.000988, and the error is 0.000023
# parameters are -0.002945 and 0.000988, and the error is 0.000022
# parameters are -0.002946 and 0.000988, and the error is 0.000021
# parameters are -0.002948 and 0.000989, and the error is 0.000021
# parameters are -0.002949 and 0.000989, and the error is 0.000020
# parameters are -0.002951 and 0.000989, and the error is 0.000020
# parameters are -0.002952 and 0.000990, and the error is 0.000019
# parameters are -0.002953 and 0.000990, and the error is 0.000019
# parameters are -0.002954 and 0.000990, and the error is 0.000018
# parameters are -0.002956 and 0.000990, and the error is 0.000018
# parameters are -0.002957 and 0.000991, and the error is 0.000017
# parameters are -0.002958 and 0.000991, and the error is 0.000017
# parameters are -0.002959 and 0.000991, and the error is 0.000016
# parameters are -0.002960 and 0.000991, and the error is 0.000016
# parameters are -0.002961 and 0.000992, and the error is 0.000016
# parameters are -0.002962 and 0.000992, and the error is 0.000015
# parameters are -0.002963 and 0.000992, and the error is 0.000015
# parameters are -0.002964 and 0.000992, and the error is 0.000014
# parameters are -0.002965 and 0.000992, and the error is 0.000014
# parameters are -0.002966 and 0.000993, and the error is 0.000014
# parameters are -0.002967 and 0.000993, and the error is 0.000013
# parameters are -0.002968 and 0.000993, and the error is 0.000013
# parameters are -0.002969 and 0.000993, and the error is 0.000013
# parameters are -0.002969 and 0.000993, and the error is 0.000012
# parameters are -0.002970 and 0.000994, and the error is 0.000012
# parameters are -0.002971 and 0.000994, and the error is 0.000012
# parameters are -0.002972 and 0.000994, and the error is 0.000011
# parameters are -0.002973 and 0.000994, and the error is 0.000011
# parameters are -0.002973 and 0.000994, and the error is 0.000011
# parameters are -0.002974 and 0.000994, and the error is 0.000010
# parameters are -0.002975 and 0.000995, and the error is 0.000010
# parameters are -0.002975 and 0.000995, and the error is 0.000010
# parameters are -0.002976 and 0.000995, and the error is 0.000010
# parameters are -0.002977 and 0.000995, and the error is 0.000009
# parameters are -0.002977 and 0.000995, and the error is 0.000009
# parameters are -0.002978 and 0.000995, and the error is 0.000009
# parameters are -0.002978 and 0.000995, and the error is 0.000009
# parameters are -0.002979 and 0.000995, and the error is 0.000008
# parameters are -0.002980 and 0.000996, and the error is 0.000008
# parameters are -0.002980 and 0.000996, and the error is 0.000008
# parameters are -0.002981 and 0.000996, and the error is 0.000008
# parameters are -0.002981 and 0.000996, and the error is 0.000008
# parameters are -0.002982 and 0.000996, and the error is 0.000007
# parameters are -0.002982 and 0.000996, and the error is 0.000007
# parameters are -0.002983 and 0.000996, and the error is 0.000007
# parameters are -0.002983 and 0.000996, and the error is 0.000007
# parameters are -0.002984 and 0.000996, and the error is 0.000007
# parameters are -0.002984 and 0.000997, and the error is 0.000006
# parameters are -0.002984 and 0.000997, and the error is 0.000006
# parameters are -0.002985 and 0.000997, and the error is 0.000006
# parameters are -0.002985 and 0.000997, and the error is 0.000006
# parameters are -0.002986 and 0.000997, and the error is 0.000006
# parameters are -0.002986 and 0.000997, and the error is 0.000006
# parameters are -0.002986 and 0.000997, and the error is 0.000005
# parameters are -0.002987 and 0.000997, and the error is 0.000005
# parameters are -0.002987 and 0.000997, and the error is 0.000005
# parameters are -0.002987 and 0.000997, and the error is 0.000005
# parameters are -0.002988 and 0.000997, and the error is 0.000005
# parameters are -0.002988 and 0.000997, and the error is 0.000005
# parameters are -0.002988 and 0.000997, and the error is 0.000005
# parameters are -0.002989 and 0.000998, and the error is 0.000005
# parameters are -0.002989 and 0.000998, and the error is 0.000004
# parameters are -0.002989 and 0.000998, and the error is 0.000004
# parameters are -0.002990 and 0.000998, and the error is 0.000004
# parameters are -0.002990 and 0.000998, and the error is 0.000004
# parameters are -0.002990 and 0.000998, and the error is 0.000004
# parameters are -0.002990 and 0.000998, and the error is 0.000004
# parameters are -0.002991 and 0.000998, and the error is 0.000004
# parameters are -0.002991 and 0.000998, and the error is 0.000004
# parameters are -0.002991 and 0.000998, and the error is 0.000004
# parameters are -0.002991 and 0.000998, and the error is 0.000003
# parameters are -0.002992 and 0.000998, and the error is 0.000003
# parameters are -0.002992 and 0.000998, and the error is 0.000003
# parameters are -0.002992 and 0.000998, and the error is 0.000003
# parameters are -0.002992 and 0.000998, and the error is 0.000003
# parameters are -0.002992 and 0.000998, and the error is 0.000003
# parameters are -0.002993 and 0.000998, and the error is 0.000003
# parameters are -0.002993 and 0.000998, and the error is 0.000003
# parameters are -0.002993 and 0.000998, and the error is 0.000003
# parameters are -0.002993 and 0.000999, and the error is 0.000003
# parameters are -0.002993 and 0.000999, and the error is 0.000003
# parameters are -0.002994 and 0.000999, and the error is 0.000003
# parameters are -0.002994 and 0.000999, and the error is 0.000003
# parameters are -0.002994 and 0.000999, and the error is 0.000002
# parameters are -0.002994 and 0.000999, and the error is 0.000002
# parameters are -0.002994 and 0.000999, and the error is 0.000002
# parameters are -0.002994 and 0.000999, and the error is 0.000002
# parameters are -0.002994 and 0.000999, and the error is 0.000002
# parameters are -0.002995 and 0.000999, and the error is 0.000002
# parameters are -0.002995 and 0.000999, and the error is 0.000002
# parameters are -0.002995 and 0.000999, and the error is 0.000002
# parameters are -0.002995 and 0.000999, and the error is 0.000002
# parameters are -0.002995 and 0.000999, and the error is 0.000002
# parameters are -0.002995 and 0.000999, and the error is 0.000002
# parameters are -0.002995 and 0.000999, and the error is 0.000002
# parameters are -0.002996 and 0.000999, and the error is 0.000002
# parameters are -0.002996 and 0.000999, and the error is 0.000002
# parameters are -0.002996 and 0.000999, and the error is 0.000002
# parameters are -0.002996 and 0.000999, and the error is 0.000002
# parameters are -0.002996 and 0.000999, and the error is 0.000002
# parameters are -0.002996 and 0.000999, and the error is 0.000002
# parameters are -0.002996 and 0.000999, and the error is 0.000002
# parameters are -0.002996 and 0.000999, and the error is 0.000001
# parameters are -0.002996 and 0.000999, and the error is 0.000001
# parameters are -0.002997 and 0.000999, and the error is 0.000001
# parameters are -0.002997 and 0.000999, and the error is 0.000001
# parameters are -0.002997 and 0.000999, and the error is 0.000001
# parameters are -0.002997 and 0.000999, and the error is 0.000001
# parameters are -0.002997 and 0.000999, and the error is 0.000001
# parameters are -0.002997 and 0.000999, and the error is 0.000001
# parameters are -0.002997 and 0.000999, and the error is 0.000001
# parameters are -0.002997 and 0.000999, and the error is 0.000001
# parameters are -0.002997 and 0.000999, and the error is 0.000001
# parameters are -0.002997 and 0.000999, and the error is 0.000001
# parameters are -0.002997 and 0.000999, and the error is 0.000001
# parameters are -0.002997 and 0.000999, and the error is 0.000001
# parameters are -0.002997 and 0.000999, and the error is 0.000001
# parameters are -0.002998 and 0.000999, and the error is 0.000001

# %%
# para_set = [0]
err_trajs_acc = []
for para in para_set:
    print(para)
    err = model2.testing(para, error_bound, acc=True)
    err_trajs_acc.append(err)
# Out:
# -4
# -4
# parameters are 0.664595 and 0.197632, the error is 0.364582, and relaxed para is 20.219868
# parameters are 0.005000 and 0.001000, the error is 0.000000, and relaxed para is 1.000000
# -2
# -2
# parameters are 0.349675 and 0.256951, the error is 0.474566, and relaxed para is 4.133558
# parameters are 0.003000 and 0.001000, the error is 0.000000, and relaxed para is 1.000000
# 0
# 0
# parameters are 0.221345 and -0.340335, the error is 0.632879, and relaxed para is 1.711788
# parameters are 0.001000 and 0.001000, the error is 0.000000, and relaxed para is 1.000000
# 2
# 2
# parameters are 0.794201 and -0.299582, the error is 0.557318, and relaxed para is 12.954559
# parameters are -0.001000 and 0.001000, the error is 0.000000, and relaxed para is 1.000000
# 4
# 4
# parameters are 0.838899 and -0.180227, the error is 0.336019, and relaxed para is 37.861871
# parameters are -0.003000 and 0.001000, the error is 0.000000, and relaxed para is 1.000000

# %%
k_optimal = model2.adapted_k()
err_optimal = model2.testing(k_optimal, error_bound, acc=False)
# Out:
#   message: ABNORMAL_TERMINATION_IN_LNSRCH
#   success: False
#    status: 2
#       fun: 3.3311094946027974e-09
#         x: [-6.455e-01]
#       nit: 5
#       jac: [ 6.407e-01]
#      nfev: 114
#      njev: 57
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
# -0.6455395250417241
# parameters are 0.001646 and -0.498669, and the error is 0.926452
# parameters are 0.001646 and 0.001000, and the error is 0.000000

# %%
import matplotlib.pyplot as plt

# Set the figure size with height:width ratio of 1:2
plt.figure(dpi=100, figsize=(8, 6))
plt.tick_params(labelsize=font_size)

# Define thicker line width
line_width = 2.5

# Plot with markers every five points
plt.plot(range(len(err_trajs[0])), err_trajs[0], color=color_dict_compare_deep['ref'], label='ν$=-4$', marker='o', markevery=10, linestyle='-', linewidth=line_width)
plt.plot(range(len(err_trajs[1])), err_trajs[1], color=color_dict_compare_deep['our'], label='ν$=-2$', marker='x', markevery=10, linestyle='-', linewidth=line_width)
plt.plot(range(len(err_trajs[2])), err_trajs[2], color=color_dict_compare_deep['compare1'], label='ν$=0$', marker='^', markevery=10, linestyle='-', linewidth=line_width)
plt.plot(range(len(err_trajs[3])), err_trajs[3], color=color_dict_compare_deep['compare2'], label='ν$=2$', marker='s', markevery=10, linestyle='-', linewidth=line_width)
plt.plot(range(len(err_trajs[4])), err_trajs[4], color=color_dict_compare_deep['compare3'], label='ν$=4$', marker='x', markevery=10, linestyle='-', linewidth=line_width)
plt.plot(range(len(err_optimal)), err_optimal, color=color_dict_compare_deep['compare4'], label='optimal ν', marker='o', markevery=10, linestyle='-', linewidth=line_width)
plt.plot(range(len(err_trajs_acc[3])), err_trajs_acc[0], color=color_dict_compare_deep['compare6'], label='acc', marker='d', markevery=10, linestyle='-', linewidth=line_width)

# Set labels and legend
plt.xlabel('Iterations', fontsize=font_size)
plt.ylabel('Error', fontsize=font_size)
plt.yscale('log')
plt.ylim(1e-7, 1e1)  # Set the y-axis limits
plt.legend(fontsize=font_size)

# Show the plot
plt.show()
